# %% [markdown]
# >[Load Colab](#scrollTo=0oVgMzR_ywr_)
#
# >[initiate](#scrollTo=2y1omcz8ywsF)
#
# >[Augmentation](#scrollTo=ft3VNQhtywsO)
#
# >[Transform](#scrollTo=L3A1UwZUywsS)
#
# >>[Check](#scrollTo=QAA2fmxbywsV)
#
# >[Train](#scrollTo=QA0eNCpVywsW)
#
# >[Plot](#scrollTo=hxjSCQMEywsZ)

# %%
# !git clone https://github.com/rcuocolo/PROSTATEx_masks
# Out:
# Cloning into 'PROSTATEx_masks'...
# remote: Enumerating objects: 5026, done.
# remote: Counting objects: 100% (376/376), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 5026 (delta 353), reused 195 (delta 179), pack-reused 4650
# Receiving objects: 100% (5026/5026), 902.72 MiB | 14.32 MiB/s, done.
# Resolving deltas: 100% (3701/3701), done.
# Updating files: 100% (2565/2565), done.

# %% [markdown]
# # Load Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#for colab
# %cd "/content/drive/MyDrive/Prostate_Lesion/"
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-a83ff8c208f9>", line 2, in <cell line: 2>
#     get_ipython().run_line_magic('cd', '"/content/drive/MyDrive/Prostate_Lesion/"')
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.9/inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.9/inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.9/inspect.py", line 738, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.9/inspect.py", line 722, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.9/posixpath.py", line 380, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-a83ff8c208f9>", line 2, in <cell line: 2>
#     get_ipython().run_line_magic('cd', '"/content/drive/MyDrive/Prostate_Lesion/"')
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.9/inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.9/inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.9/inspect.py", line 738, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.9/inspect.py", line 722, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.9/posixpath.py", line 380, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-a83ff8c208f9>", line 2, in <cell line: 2>
#     get_ipython().run_line_magic('cd', '"/content/drive/MyDrive/Prostate_Lesion/"')
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.9/inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.9/inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.9/inspect.py", line 738, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.9/inspect.py", line 722, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.9/posixpath.py", line 380, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
# %pip install -r requirement.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting monai
#   Downloading monai-1.1.0-202212191849-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 36.5 MB/s eta 0:00:00
# Collecting dicom2nifti
#   Downloading dicom2nifti-2.4.8-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from -r requirement.txt (line 3)) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from -r requirement.txt (line 4)) (4.65.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from -r requirement.txt (line 5)) (3.7.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from -r requirement.txt (line 6)) (7.7.1)
# Collecting elasticdeform
#   Downloading elasticdeform-0.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.3/91.3 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.9/dist-packages (from -r requirement.txt (line 8)) (0.19.3)
# Collecting torchmetrics
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 29.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.9/dist-packages (from monai->-r requirement.txt (line 1)) (2.0.0+cu118)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from monai->-r requirement.txt (line 1)) (1.22.4)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.9/dist-packages (from dicom2nifti->-r requirement.txt (line 2)) (3.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from dicom2nifti->-r requirement.txt (line 2)) (1.10.1)
# Collecting python-gdcm
#   Downloading python_gdcm-3.0.21-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 19.3 MB/s eta 0:00:00
# Collecting pydicom>=2.2.0
#   Downloading pydicom-2.3.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 71.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->-r requirement.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->-r requirement.txt (line 3)) (2022.7.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirement.txt (line 5)) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirement.txt (line 5)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirement.txt (line 5)) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirement.txt (line 5)) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirement.txt (line 5)) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirement.txt (line 5)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirement.txt (line 5)) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirement.txt (line 5)) (1.4.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r requirement.txt (line 6)) (7.34.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r requirement.txt (line 6)) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r requirement.txt (line 6)) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r requirement.txt (line 6)) (3.6.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r requirement.txt (line 6)) (3.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r requirement.txt (line 6)) (5.5.6)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->-r requirement.txt (line 8)) (1.4.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image->-r requirement.txt (line 8)) (3.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image->-r requirement.txt (line 8)) (2023.4.12)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->-r requirement.txt (line 8)) (2.25.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->-r requirement.txt (line 5)) (3.15.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r requirement.txt (line 6)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r requirement.txt (line 6)) (6.2)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (67.6.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (0.1.6)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (2.14.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (3.0.38)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (4.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->-r requirement.txt (line 3)) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.8->monai->-r requirement.txt (line 1)) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.8->monai->-r requirement.txt (line 1)) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.8->monai->-r requirement.txt (line 1)) (3.11.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.8->monai->-r requirement.txt (line 1)) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.8->monai->-r requirement.txt (line 1)) (4.5.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.8->monai->-r requirement.txt (line 1)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.8->monai->-r requirement.txt (line 1)) (16.0.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (6.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (0.8.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (1.5.6)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (5.3.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (0.16.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (6.5.4)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (23.2.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (5.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->-r requirement.txt (line 6)) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.8->monai->-r requirement.txt (line 1)) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.8->monai->-r requirement.txt (line 1)) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (3.2.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (21.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (4.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (4.11.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (6.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (0.8.4)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (0.7.3)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (0.2.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirement.txt (line 6)) (2.21)
# Installing collected packages: python-gdcm, pydicom, jedi, elasticdeform, dicom2nifti, torchmetrics, monai
# Successfully installed dicom2nifti-2.4.8 elasticdeform-0.5.0 jedi-0.18.2 monai-1.1.0 pydicom-2.3.1 python-gdcm-3.0.21 torchmetrics-0.11.4

# %% [markdown]
# # initiate

# %%
import pandas as pd
import nibabel as nib
import os
from glob import glob
import shutil
from tqdm import tqdm
import dicom2nifti
import numpy as np
import nibabel as nib
import pandas as pd


import json
import matplotlib.pyplot as plt
# %matplotlib inline
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
import os

from monai.utils import first

# %%
HOME_DIR =       "./"
DATA_DIR =       "./PROSTATEx_masks/Files/lesions/"
OUT_DIR =        "./results/lesion/"
SLICED_OUT_DIR = "./data/sliced/"
AUG_OUT_DIR = "./data/augmented/"

# %%
df = pd.read_csv('/content/drive/MyDrive/Prostate_Lesion/PROSTATEx_masks/Files/lesions/Image_list.csv')

# %%
import os
if not os.path.exists(SLICED_OUT_DIR + "images/"):
    os.makedirs(SLICED_OUT_DIR + "images/")
if not os.path.exists(SLICED_OUT_DIR + "prostates/"):
    os.makedirs(SLICED_OUT_DIR + "prostates/")
if not os.path.exists(SLICED_OUT_DIR + "pz_masks/"):
    os.makedirs(SLICED_OUT_DIR + "pz_masks/")
if not os.path.exists(SLICED_OUT_DIR + "tz_masks/"):
    os.makedirs(SLICED_OUT_DIR + "tz_masks/")
if not os.path.exists(SLICED_OUT_DIR + "labels/"):
    os.makedirs(SLICED_OUT_DIR + "labels/")

# %%
data = []
for index, row in df.iterrows():
    value = row['T2'].split("-")
    numb= value[1].split("_")[0]
    if int(numb) == 128:
        t2 = DATA_DIR+'Images/T2/'+row['T2']+'.nii'
    else:
        t2 = DATA_DIR+'Images/T2/'+row['T2']+'.nii.gz'
    if int(numb) == 25:
        adc = DATA_DIR+'Images/ADC/'+row['ADC']+'a.nii.gz'
    elif int(numb) == 113:
        value = row['ADC'][:-2]+'9'
        adc = DATA_DIR+'Images/ADC/'+value+'.nii.gz'
    elif int(numb) == 203:
        adc = DATA_DIR+'Images/ADC/'+'ProstateX-0203_diffusie-3ProstateX-0203_diffusie-3Scan-4bval_fs_7.niiScan-4bval_fs_7.nii.gz'
    else:
        adc = DATA_DIR+'Images/ADC/'+row['ADC']+'.nii.gz'
   
    data.append({ 'T2': t2, 'ADC': adc , 'name': value[0] + '_' +str(numb)})

# %%
import nibabel as nib
import json
import numpy as np

def load_nifti(image_nifty_file, label_nifty_file):
    # load the image and label file, get the image content and return a numpy array for each
    image = nib.load(image_nifty_file)
    label = nib.load(label_nifty_file)
    
    return image, label

def save_to_json(data, path):
  with open(path, 'w') as fp:
    json.dump(data, fp)


def remove_slices(img,start, end):
  imgvol = np.array( img.dataobj )
  imgvol = imgvol[ :, :, start:end ]
  newimg = nib.Nifti1Image ( imgvol, img.affine )
  return newimg

# %%
df = pd.read_csv(DATA_DIR +'image_list.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-d10d5a774404> in <cell line: 1>()
# ----> 1 df = pd.read_csv(DATA_DIR +'image_list.csv')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './PROSTATEx_masks/Files/lesions/image_list.csv'

# %%
import os
import nibabel as nib

# specify the directory path
image_path = './PROSTATEx_masks/Files/prostate/Images/'
prostate_path = './PROSTATEx_masks/Files/prostate/mask_prostate/'
pz_path = './PROSTATEx_masks/Files/prostate/mask_pz/'
tz_path = './PROSTATEx_masks/Files/prostate/mask_tz/'
lesion_path = './PROSTATEx_masks/Files/lesions/Masks/T2/'
#t2_path = './PROSTATEx_masks/Files/lesions/Images/T2/'
#adc_path = './PROSTATEx_masks/Files/lesions/Masks/ADC/'

# get all the file names in the directory
t2_images = os.listdir(image_path)
prostates = os.listdir(prostate_path)
pz_images = os.listdir(pz_path)
tz_images = os.listdir(tz_path)
t2_lesions = os.listdir(lesion_path)
#t2_2 = os.listdir(t2_path)
#adc_images = os.listdir(adc_path)

data = []
for i in range(len(df['T2'])):
    t2 = nib.load(image_path + t2_images[i])
    prostate = nib.load(prostate_path + prostates[i])
    pz = nib.load(pz_path + pz_images[i])
    tz = nib.load(tz_path + tz_images[i])
    lesion = nib.load(lesion_path + t2_lesions[i])
    name = t2_images[i].split('_')[0]

    
    if t2.shape[2] == lesion.shape[2]:
        path = {
            'T2': image_path + t2_images[i],
            'prostate': prostate_path + prostates[i],
            'PZ' : pz_path + pz_images[i],
            'TZ': tz_path + tz_images[i],
            'label': lesion_path + t2_lesions[i],
            'Name':name
        }
        data.append(path)

# %%
import nibabel as nib
import json
import numpy as np

def load_nifti(image_path_1,image_path_2,image_path_3,image_path_4, label_path):
    # load the image and label file, get the image content and return a numpy array for each
    image1 = nib.load(image_path_1)
    image2 = nib.load(image_path_2)
    image3 = nib.load(image_path_3)
    image4 = nib.load(image_path_4)
    label = nib.load(label_path)
    
    return image1,image2,image3,image4, label

def save_to_json(data, path):
  with open(path, 'w') as fp:
    json.dump(data, fp)


def remove_slice(img,  slice_size):
    total_slize_size = img.shape[2]
    extra_slices = total_slize_size - slice_size
    end  = total_slize_size - (extra_slices // 2 )
    start = end - slice_size 
    imgvol = np.array( img.dataobj )
    imgvol = imgvol[ :, :, start:end ]
    newimg = nib.Nifti1Image ( imgvol, img.affine )
    return newimg

def create_same_slice_nifti(data, slice_size ,dir):
  paths = []
  total = len(data)
  count = 1
  for entry in data:
    image, prostate, pz , tz, label = load_nifti(entry["T2"], entry["prostate"], entry["PZ"], entry["TZ"], entry["label"])

    total_slize_size = min( image.shape[2], prostate.shape[2], pz.shape[2] , tz.shape[2], label.shape[2])
    if(total_slize_size < slice_size): 
      print("ERROR: slice upper limit exceeds")
      continue
    

    new_image = remove_slice(image,slice_size)
    new_prostate = remove_slice(prostate,slice_size)
    new_pz = remove_slice(pz,slice_size)
    new_tz = remove_slice(tz,slice_size)
    new_lbl = remove_slice(label,slice_size)

    image_path = dir + 'images/'+ entry['Name']+'.nii.gz'
    label_path = dir + 'labels/' + entry['Name']+'.nii.gz'
    prostate_path = dir + 'prostates/' + entry['Name']+'.nii.gz'
    pz_path = dir + 'pz_masks/' + entry['Name']+'.nii.gz'
    tz_path = dir + 'tz_masks/' + entry['Name']+'.nii.gz'
    
    paths.append({
      "image":image_path, 
      'prostate':prostate_path,
      'PZ': pz_path,
      'TZ' : tz_path,
      "label":label_path, 
    })
    new_image.to_filename(image_path)
    new_prostate.to_filename(prostate_path)
    new_pz.to_filename(pz_path)
    new_tz.to_filename(tz_path)
    new_lbl.to_filename(label_path)
    
    print(f"{count}/{total}")
    count += 1

  save_to_json({"path": paths}, dir + 'config.json')

# %%
slice_size = 16
create_same_slice_nifti(data, slice_size ,SLICED_OUT_DIR)

# %% [markdown]
# # Augmentation

# %%
def get_data_path(path):
  f = open( path + 'config.json')
  jdata = json.load(f)
  f.close()
  return jdata["path"]

# %%
data = get_data_path(SLICED_OUT_DIR)

# %%
import nibabel as nib
import random
import elasticdeform 
import numpy as np
import nibabel as nib

from scipy.ndimage import affine_transform, rotate, zoom
from skimage.exposure import adjust_gamma, rescale_intensity
from skimage.util import random_noise

# %%
def random_flip_rotate_zoom_translate(image,PZ, TZ, Prostate, label):
    angle = random.uniform(-5, 5)
    flip_axes = [ i for i in range(2) if i!=2 and np.random.choice([0, 1]) == 1]
    translate = (random.uniform(-10,10), random.uniform(-10,10))
    matrix = np.array([[1, 0, 0, translate[0]], [0, 1, 0, translate[1]], [0, 0, 1,  0], [0, 0, 0, 1]])

    imgvol = np.array(image.dataobj)
    lblvol = np.array(label.dataobj)
    pzvol = np.array(PZ.dataobj)
    tzvol = np.array(TZ.dataobj)
    prostatevol = np.array(Prostate.dataobj)

    # Rotate
    img = rotate(imgvol, angle, reshape=False)
    lbl = rotate(lblvol, angle, reshape=False)
    pz = rotate(pzvol, angle, reshape=False)
    tz = rotate(tzvol, angle, reshape=False)
    prostate = rotate(prostatevol, angle, reshape=False)

    # Randomly flip the image and label along one or more axes, except for the z-axis
    img = np.flip(img, axis=flip_axes)
    lbl = np.flip(lbl, axis=flip_axes)
    pz = np.flip(pz, axis=flip_axes)
    tz = np.flip(tz, axis=flip_axes)
    prostate = np.flip(prostate, axis=flip_axes)
    

    # zoom
    zoom_factor = random.uniform(0.8, 1.2)
    img = zoom(img, zoom_factor, order=1)
    pz = zoom( pz, zoom_factor, order=0)
    tz = zoom(tz, zoom_factor, order=0)
    prostate = zoom(prostate, zoom_factor, order=0)
    lbl = zoom(lbl, zoom_factor, order=0)

    # Translate
    img = affine_transform(img, matrix, order=1)
    pz = affine_transform(pz, matrix, order=0)
    tz = affine_transform(tz, matrix, order=0)
    prostate = affine_transform(prostate, matrix, order=0)
    lbl = affine_transform(lbl, matrix, order=0)

    image = nib.Nifti1Image(img, image.affine)
    pz = nib.Nifti1Image(pz, PZ.affine)
    tz = nib.Nifti1Image(tz, TZ.affine)
    prostate = nib.Nifti1Image(prostate, Prostate.affine)
    label = nib.Nifti1Image(lbl, label.affine)
    return image, pz, tz, prostate, label

# %%
def load_nifti(image_path_1,image_path_2,image_path_3,image_path_4, label_path):
    # load the image and label file, get the image content and return a numpy array for each
    image1 = nib.load(image_path_1)
    image2 = nib.load(image_path_2)
    image3 = nib.load(image_path_3)
    image4 = nib.load(image_path_4)
    label = nib.load(label_path)
    
    return image1,image2,image3,image4, label

# %%
def save_to_json(data, path):
  with open(path, 'w') as fp:
    json.dump(data, fp)

# %%
import os
times = ['fold1','fold2', 'fold3']
for fold in times:
    if not os.path.exists(AUG_OUT_DIR + fold + "/images/"):
        os.makedirs(AUG_OUT_DIR + fold + "/images/")
    if not os.path.exists(AUG_OUT_DIR + fold + "/prostates/"):
        os.makedirs(AUG_OUT_DIR + fold + "/prostates/")
    if not os.path.exists(AUG_OUT_DIR + fold + "/pz_masks/"):
        os.makedirs(AUG_OUT_DIR + fold + "/pz_masks/")
    if not os.path.exists(AUG_OUT_DIR + fold + "/tz_masks/"):
        os.makedirs(AUG_OUT_DIR + fold + "/tz_masks/")
    if not os.path.exists(AUG_OUT_DIR + fold + "/labels/"):
        os.makedirs(AUG_OUT_DIR + fold + "/labels/")

# %%
paths = []
dir = AUG_OUT_DIR
times = ['fold1','fold2', 'fold3']
for fold in times:
  for entry in data:
      image, Prostate, PZ , TZ, label = load_nifti(entry["image"], entry["prostate"], entry["PZ"], entry["TZ"], entry["label"])
      
      image, pz, tz, prostate, label = random_flip_rotate_zoom_translate(image,PZ, TZ, Prostate, label)

      image_path = entry["image"].replace("data/sliced", "data/augmented/" + fold)
      label_path = entry["label"].replace("data/sliced", "data/augmented/" + fold)
      prostate_path = entry["prostate"].replace("data/sliced", "data/augmented/" + fold)
      pz_path = entry["PZ"].replace("data/sliced", "data/augmented/" + fold)
      tz_path = entry["TZ"].replace("data/sliced", "data/augmented/" + fold)
      

      image.to_filename(image_path)
      prostate.to_filename(prostate_path)
      pz.to_filename(pz_path)
      tz.to_filename(tz_path)
      label.to_filename(label_path)

      paths.append({
        "image":image_path, 
        'prostate':prostate_path,
        'PZ': pz_path,
        'TZ' : tz_path,
        "label":label_path, 
      })

      

save_to_json({"path": paths}, AUG_OUT_DIR + 'config.json')
# Out:
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (320, 320, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (320, 320, 16) (320, 320, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (320, 320, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (640, 640, 16) (640, 640, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (640, 640, 16) (640, 640, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (320, 320, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (640, 640, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (320, 320, 16) (320, 320, 16) (384, 384, 16)
# (384, 384, 16) (320, 320, 16) (320, 320, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (320, 320, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (320, 320, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (320, 320, 16) (320, 320, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (320, 320, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (640, 640, 16) (640, 640, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (640, 640, 16) (640, 640, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (320, 320, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (640, 640, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (320, 320, 16) (320, 320, 16) (384, 384, 16)
# (384, 384, 16) (320, 320, 16) (320, 320, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (320, 320, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (320, 320, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (320, 320, 16) (320, 320, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (320, 320, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (640, 640, 16) (640, 640, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (640, 640, 16) (640, 640, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (320, 320, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (640, 640, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (320, 320, 16) (320, 320, 16) (384, 384, 16)
# (384, 384, 16) (320, 320, 16) (320, 320, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (384, 384, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)
# (320, 320, 16) (384, 384, 16) (384, 384, 16) (384, 384, 16)

# %% [markdown]
# # Transform

# %%
def get_data_path(path):
  f = open( path + 'config.json')
  jdata = json.load(f)
  f.close()
  return jdata["path"]

# %%
data = get_data_path(SLICED_OUT_DIR)
aug_data = get_data_path(AUG_OUT_DIR)
print(len(data))

train_size = int(0.8 * len(data))
aug_train_size = int(0.8 * len(aug_data))
train_data =  data[:train_size] + aug_data[:aug_train_size]
test_data = data[train_size:] + aug_data[aug_train_size:]
# Out:
# 75

# %%
len(train_data)
# Out:
# 240

# %%
pixdim =(1.5, 1.5, 1.0)
a_min=0
a_max=500
spatial_size= [128, 128,16] #[384, 384,18]

# %%
import numpy as np
from monai.transforms import (
    Compose,
    AddChanneld,
    LoadImaged,
    Resized,
    ToTensord,
    Spacingd,
    Orientationd,
    ScaleIntensityRanged,
    CropForegroundd,
    SqueezeDimd
)
from monai.data import DataLoader, Dataset


class ConcatImagesd:
    def __init__(self, keys):
        self.keys = keys

    def __call__(self, data):
        concat = np.concatenate([np.expand_dims(data[key], axis=0) for key in self.keys], axis=1)
        data[self.keys[0]] = concat
        for key in self.keys[1:]:
            del data[key]
        return data


def transform(data, a_min, a_max, spatial_size, pixdim):
    train_transforms = Compose([
        LoadImaged(keys=["image", "PZ", "TZ", "prostate", "label"], reader="ITKReader"),
        AddChanneld(keys=["label"]),
        AddChanneld(keys=["image", "PZ", "TZ", "prostate"]),
        Orientationd(keys=["image", "PZ", "TZ", "prostate", "label"], axcodes="RAS"),
        ScaleIntensityRanged(keys=["image"], a_min=a_min, a_max=a_max, b_min=0.0, b_max=1.0, clip=True),
        CropForegroundd(keys=["image", "PZ", "TZ", "prostate", "label"], source_key="image"),
        Resized(keys=["image", "PZ", "TZ", "prostate", "label"], spatial_size=spatial_size),
        ConcatImagesd(keys=["image", "PZ", "TZ", "prostate"]),
        ToTensord(keys=["image", "label"]),
        SqueezeDimd(keys=["image"]),
    ])

    ds = Dataset(data=data, transform=train_transforms)
    loader = DataLoader(ds, batch_size=1)

    return loader

# %%
#from utils.transform import transform

train_loader = transform(train_data, a_min, a_max, spatial_size, pixdim)
test_loader = transform(test_data, a_min, a_max, spatial_size, pixdim)
# Out:
# c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\transforms\io\array.py:199: UserWarning: required package for reader ITKReader is not installed, or the version doesn't match requirement.
#   warnings.warn(
# c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\utils\deprecate_utils.py:107: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead.
#   warn_deprecated(obj, msg, warning_category)

# %% [markdown]
# ## Check

# %%
# first image, label from orignal image
imagea =nib.load(data[0]["image"]).get_fdata()
labela =nib.load(data[0]["label"]).get_fdata()
print(imagea.shape,labela.shape)

# %%
# first image, label from preprossed image
image1= first(train_loader)["image"]
label1 = first(train_loader)["label"]
print(image1.shape,label1.shape)
image11 =image1.get_array()
label11 = label1.get_array()
# Out:
# torch.Size([1, 4, 128, 128, 16]) torch.Size([1, 1, 128, 128, 16])

# %%
# Define a function to visualize the data
def explore_3dimage2(layer):
    plt.figure(figsize=(10, 5))
    channel = 2
    # plt.imshow(image11[0,0,:,:,layer], cmap='gray');
    # plt.title('Explore Layers of Prostate MRI', fontsize=20)
    # plt.axis('off')
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

    ax[0].imshow(image1[0,0,:,:,layer], cmap='gray')
    ax[0].set_title(f"Image", fontsize=15)
    ax[0].axis('off')

    ax[1].imshow(label1[0,0,:,:,layer])
    ax[1].axis('off')
    return

# %%
# Explore the preprocessed image, label
interact(explore_3dimage2, layer=(0, 15))
# Out:
# interactive(children=(IntSlider(value=7, description='layer', max=15), Output()), _dom_classes=('widget-intera…
# <function __main__.explore_3dimage2(layer)>

# %% [markdown]
# # Train

# %%
from monai.utils import first
import matplotlib.pyplot as plt
import torch
import os
import numpy as np
from monai.losses import DiceLoss
from tqdm import tqdm
from utils.train import train

# %%
model_dir = OUT_DIR 
data_in = [train_loader, test_loader]

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from monai.networks.nets import UNet
from monai.networks.layers import Norm

unet = UNet(
    spatial_dims=3,
    in_channels=4,
    out_channels=1,
    channels=( 64, 128, 256,512), 
    strides=(2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

# %%
#loss_function = DiceCELoss(to_onehot_y=True, sigmoid=True, squared_pred=True, ce_weight=calculate_weights(1792651250,2510860).to(device))
loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(unet.parameters(), 1e-4, weight_decay=1e-5, amsgrad=True)

# %%
model_dir = OUT_DIR + "unet/"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
import os.path

path = OUT_DIR+ "unet/"+ "best_metric_model.pth"

if (os.path.exists(path)):
    unet.load_state_dict(torch.load(
        os.path.join(path)))

# %%
train(unet, data_in, loss_function, optimizer, 10, model_dir, test_interval=2,start_from=1)
# Out:
# ----------
# epoch 1/10
# /usr/local/lib/python3.9/dist-packages/monai/losses/dice.py:144: UserWarning: single channel prediction, `to_onehot_y=True` ignored.
#   warnings.warn("single channel prediction, `to_onehot_y=True` ignored.")
# 1/239, Train_loss: 0.9985 Train_dice: 0.0015
# 2/239, Train_loss: 0.9972 Train_dice: 0.0028
# 3/239, Train_loss: 0.9964 Train_dice: 0.0036
# 4/239, Train_loss: 0.9967 Train_dice: 0.0033
# 5/239, Train_loss: 0.9910 Train_dice: 0.0090
# 6/239, Train_loss: 0.9935 Train_dice: 0.0065
# 7/239, Train_loss: 0.9743 Train_dice: 0.0257
# 8/239, Train_loss: 0.9981 Train_dice: 0.0019
# 9/239, Train_loss: 0.9989 Train_dice: 0.0011
# 10/239, Train_loss: 0.9882 Train_dice: 0.0118
# 11/239, Train_loss: 0.9904 Train_dice: 0.0096
# 12/239, Train_loss: 0.9947 Train_dice: 0.0053
# 13/239, Train_loss: 0.9958 Train_dice: 0.0042
# 14/239, Train_loss: 0.9910 Train_dice: 0.0090
# 15/239, Train_loss: 0.9928 Train_dice: 0.0072
# 16/239, Train_loss: 0.9956 Train_dice: 0.0044
# 17/239, Train_loss: 0.9895 Train_dice: 0.0105
# 18/239, Train_loss: 0.9982 Train_dice: 0.0018
# 19/239, Train_loss: 0.9920 Train_dice: 0.0080
# 20/239, Train_loss: 0.9629 Train_dice: 0.0371
# 21/239, Train_loss: 0.9971 Train_dice: 0.0029
# 22/239, Train_loss: 0.9971 Train_dice: 0.0029
# 23/239, Train_loss: 0.9862 Train_dice: 0.0138
# 24/239, Train_loss: 0.9745 Train_dice: 0.0255
# 25/239, Train_loss: 0.9965 Train_dice: 0.0035
# 26/239, Train_loss: 0.9963 Train_dice: 0.0037
# 27/239, Train_loss: 0.9977 Train_dice: 0.0023
# 28/239, Train_loss: 0.9805 Train_dice: 0.0195

# %%
from Models.ModifiedNet import MNet

mnet = MNet()

# %%
#loss_function = DiceCELoss(to_onehot_y=True, sigmoid=True, squared_pred=True, ce_weight=calculate_weights(1792651250,2510860).to(device))
loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(unet.parameters(), 1e-4, weight_decay=1e-5, amsgrad=True)

# %%
train(unet, data_in, loss_function, optimizer, 10, model_dir, test_interval=2,start_from=1)
# Out:
# ----------
# epoch 1/10
# c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\losses\dice.py:144: UserWarning: single channel prediction, `to_onehot_y=True` ignored.
#   warnings.warn("single channel prediction, `to_onehot_y=True` ignored.")
# 1/240, Train_loss: 0.9959 Train_dice: 0.0041
# 2/240, Train_loss: 0.9941 Train_dice: 0.0059
# 3/240, Train_loss: 0.9932 Train_dice: 0.0068
# 4/240, Train_loss: 0.9604 Train_dice: 0.0396
# 5/240, Train_loss: 0.9903 Train_dice: 0.0097
# 6/240, Train_loss: 0.9964 Train_dice: 0.0036
# 7/240, Train_loss: 0.9897 Train_dice: 0.0103
# 8/240, Train_loss: 0.9606 Train_dice: 0.0394
# 9/240, Train_loss: 0.9960 Train_dice: 0.0040
# 10/240, Train_loss: 0.9820 Train_dice: 0.0180
# 11/240, Train_loss: 0.9688 Train_dice: 0.0312
# 12/240, Train_loss: 0.9955 Train_dice: 0.0045
# 13/240, Train_loss: 0.9969 Train_dice: 0.0031
# 14/240, Train_loss: 0.9942 Train_dice: 0.0058
# 15/240, Train_loss: 0.9910 Train_dice: 0.0090
# 16/240, Train_loss: 0.9878 Train_dice: 0.0122
# 17/240, Train_loss: 0.9769 Train_dice: 0.0231
# 18/240, Train_loss: 0.9955 Train_dice: 0.0045
# 19/240, Train_loss: 0.9972 Train_dice: 0.0028
# 20/240, Train_loss: 0.9917 Train_dice: 0.0083
# 21/240, Train_loss: 0.9750 Train_dice: 0.0250
# 22/240, Train_loss: 0.9909 Train_dice: 0.0091
# 23/240, Train_loss: 0.9944 Train_dice: 0.0056
# 24/240, Train_loss: 0.9865 Train_dice: 0.0135
# 25/240, Train_loss: 0.9844 Train_dice: 0.0156
# 26/240, Train_loss: 0.9245 Train_dice: 0.0755
# 27/240, Train_loss: 0.9861 Train_dice: 0.0139
# 28/240, Train_loss: 0.9910 Train_dice: 0.0090
# 29/240, Train_loss: 0.9841 Train_dice: 0.0159
# 30/240, Train_loss: 0.9967 Train_dice: 0.0033
# 31/240, Train_loss: 0.9981 Train_dice: 0.0019
# 32/240, Train_loss: 0.9958 Train_dice: 0.0042
# 33/240, Train_loss: 0.9974 Train_dice: 0.0026
# 34/240, Train_loss: 0.9987 Train_dice: 0.0013
# 35/240, Train_loss: 0.9925 Train_dice: 0.0075
# 36/240, Train_loss: 0.9931 Train_dice: 0.0069
# 37/240, Train_loss: 0.9977 Train_dice: 0.0023
# 38/240, Train_loss: 0.9977 Train_dice: 0.0023
# 39/240, Train_loss: 0.9950 Train_dice: 0.0050
# 40/240, Train_loss: 0.9860 Train_dice: 0.0140
# 41/240, Train_loss: 0.9898 Train_dice: 0.0102
# 42/240, Train_loss: 0.9841 Train_dice: 0.0159
# 43/240, Train_loss: 0.9970 Train_dice: 0.0030
# 44/240, Train_loss: 0.9960 Train_dice: 0.0040
# 45/240, Train_loss: 0.9899 Train_dice: 0.0101
# 46/240, Train_loss: 0.9951 Train_dice: 0.0049
# 47/240, Train_loss: 0.9965 Train_dice: 0.0035
# 48/240, Train_loss: 0.9921 Train_dice: 0.0079
# 49/240, Train_loss: 0.9698 Train_dice: 0.0302
# 50/240, Train_loss: 0.9957 Train_dice: 0.0043
# 51/240, Train_loss: 0.9884 Train_dice: 0.0116
# 52/240, Train_loss: 0.9901 Train_dice: 0.0099
# 53/240, Train_loss: 0.9966 Train_dice: 0.0034
# 54/240, Train_loss: 0.9565 Train_dice: 0.0435
# 55/240, Train_loss: 0.9994 Train_dice: 0.0006
# 56/240, Train_loss: 0.9883 Train_dice: 0.0117
# 57/240, Train_loss: 0.9934 Train_dice: 0.0066
# 58/240, Train_loss: 0.9933 Train_dice: 0.0067
# 59/240, Train_loss: 0.9946 Train_dice: 0.0054
# 60/240, Train_loss: 0.9929 Train_dice: 0.0071
# 61/240, Train_loss: 0.9932 Train_dice: 0.0068
# 62/240, Train_loss: 0.9924 Train_dice: 0.0076
# 63/240, Train_loss: 0.9886 Train_dice: 0.0114
# 64/240, Train_loss: 0.9514 Train_dice: 0.0486
# 65/240, Train_loss: 0.9887 Train_dice: 0.0113
# 66/240, Train_loss: 0.9929 Train_dice: 0.0071
# 67/240, Train_loss: 0.9814 Train_dice: 0.0186
# 68/240, Train_loss: 0.9447 Train_dice: 0.0553
# 69/240, Train_loss: 0.9940 Train_dice: 0.0060
# 70/240, Train_loss: 0.9786 Train_dice: 0.0214
# 71/240, Train_loss: 0.9568 Train_dice: 0.0432
# 72/240, Train_loss: 0.9922 Train_dice: 0.0078
# 73/240, Train_loss: 0.9980 Train_dice: 0.0020
# 74/240, Train_loss: 0.9946 Train_dice: 0.0054
# 75/240, Train_loss: 0.9856 Train_dice: 0.0144
# 76/240, Train_loss: 0.9803 Train_dice: 0.0197
# 77/240, Train_loss: 0.9685 Train_dice: 0.0315
# 78/240, Train_loss: 0.9956 Train_dice: 0.0044
# 79/240, Train_loss: 0.9949 Train_dice: 0.0051
# 80/240, Train_loss: 0.9871 Train_dice: 0.0129
# 81/240, Train_loss: 0.9687 Train_dice: 0.0313
# 82/240, Train_loss: 0.9867 Train_dice: 0.0133
# 83/240, Train_loss: 0.9916 Train_dice: 0.0084
# 84/240, Train_loss: 0.9857 Train_dice: 0.0143
# 85/240, Train_loss: 0.9793 Train_dice: 0.0207
# 86/240, Train_loss: 0.8969 Train_dice: 0.1031
# 87/240, Train_loss: 0.9821 Train_dice: 0.0179
# 88/240, Train_loss: 0.9852 Train_dice: 0.0148
# 89/240, Train_loss: 0.9701 Train_dice: 0.0299
# 90/240, Train_loss: 0.9951 Train_dice: 0.0049
# 91/240, Train_loss: 0.9969 Train_dice: 0.0031
# 92/240, Train_loss: 0.9921 Train_dice: 0.0079
# 93/240, Train_loss: 0.9953 Train_dice: 0.0047
# 94/240, Train_loss: 0.9987 Train_dice: 0.0013
# 95/240, Train_loss: 0.9892 Train_dice: 0.0108
# 96/240, Train_loss: 0.9885 Train_dice: 0.0115
# 97/240, Train_loss: 0.9897 Train_dice: 0.0103
# 98/240, Train_loss: 0.9962 Train_dice: 0.0038
# 99/240, Train_loss: 0.9940 Train_dice: 0.0060
# 100/240, Train_loss: 0.9865 Train_dice: 0.0135
# 101/240, Train_loss: 0.9897 Train_dice: 0.0103
# 102/240, Train_loss: 0.9772 Train_dice: 0.0228
# 103/240, Train_loss: 0.9956 Train_dice: 0.0044
# 104/240, Train_loss: 0.9958 Train_dice: 0.0042
# 105/240, Train_loss: 0.9859 Train_dice: 0.0141
# 106/240, Train_loss: 0.9934 Train_dice: 0.0066
# 107/240, Train_loss: 0.9959 Train_dice: 0.0041
# 108/240, Train_loss: 0.9861 Train_dice: 0.0139
# 109/240, Train_loss: 0.9617 Train_dice: 0.0383
# 110/240, Train_loss: 0.9941 Train_dice: 0.0059
# 111/240, Train_loss: 0.9822 Train_dice: 0.0178
# 112/240, Train_loss: 0.9860 Train_dice: 0.0140
# 113/240, Train_loss: 0.9967 Train_dice: 0.0033
# 114/240, Train_loss: 0.9524 Train_dice: 0.0476
# 115/240, Train_loss: 0.9989 Train_dice: 0.0011
# 116/240, Train_loss: 0.9873 Train_dice: 0.0127
# 117/240, Train_loss: 0.9878 Train_dice: 0.0122
# 118/240, Train_loss: 0.9914 Train_dice: 0.0086
# 119/240, Train_loss: 0.9909 Train_dice: 0.0091
# 120/240, Train_loss: 0.9919 Train_dice: 0.0081
# 121/240, Train_loss: 0.9968 Train_dice: 0.0032
# 122/240, Train_loss: 0.9792 Train_dice: 0.0208
# 123/240, Train_loss: 0.9941 Train_dice: 0.0059
# 124/240, Train_loss: 0.9960 Train_dice: 0.0040
# 125/240, Train_loss: 0.9442 Train_dice: 0.0558
# 126/240, Train_loss: 0.9940 Train_dice: 0.0060
# 127/240, Train_loss: 0.9959 Train_dice: 0.0041
# 128/240, Train_loss: 0.9897 Train_dice: 0.0103
# 129/240, Train_loss: 0.9979 Train_dice: 0.0021
# 130/240, Train_loss: 0.9873 Train_dice: 0.0127
# 131/240, Train_loss: 0.9868 Train_dice: 0.0132
# 132/240, Train_loss: 1.0000 Train_dice: 0.0000
# 133/240, Train_loss: 0.9995 Train_dice: 0.0005
# 134/240, Train_loss: 0.9909 Train_dice: 0.0091
# 135/240, Train_loss: 0.9866 Train_dice: 0.0134
# 136/240, Train_loss: 0.9928 Train_dice: 0.0072
# 137/240, Train_loss: 0.9888 Train_dice: 0.0112
# 138/240, Train_loss: 0.9916 Train_dice: 0.0084
# 139/240, Train_loss: 0.9490 Train_dice: 0.0510
# 140/240, Train_loss: 0.9895 Train_dice: 0.0105
# 141/240, Train_loss: 0.9941 Train_dice: 0.0059
# 142/240, Train_loss: 0.9894 Train_dice: 0.0106
# 143/240, Train_loss: 0.9356 Train_dice: 0.0644
# 144/240, Train_loss: 0.9936 Train_dice: 0.0064
# 145/240, Train_loss: 0.9609 Train_dice: 0.0391
# 146/240, Train_loss: 0.9563 Train_dice: 0.0437
# 147/240, Train_loss: 0.9945 Train_dice: 0.0055
# 148/240, Train_loss: 0.9948 Train_dice: 0.0052
# 149/240, Train_loss: 0.9920 Train_dice: 0.0080
# 150/240, Train_loss: 0.9853 Train_dice: 0.0147
# 151/240, Train_loss: 0.9822 Train_dice: 0.0178
# 152/240, Train_loss: 0.9668 Train_dice: 0.0332
# 153/240, Train_loss: 0.9915 Train_dice: 0.0085
# 154/240, Train_loss: 0.9944 Train_dice: 0.0056
# 155/240, Train_loss: 0.9885 Train_dice: 0.0115
# 156/240, Train_loss: 0.9611 Train_dice: 0.0389
# 157/240, Train_loss: 0.9851 Train_dice: 0.0149
# 158/240, Train_loss: 0.9915 Train_dice: 0.0085
# 159/240, Train_loss: 0.9782 Train_dice: 0.0218
# 160/240, Train_loss: 0.9891 Train_dice: 0.0109
# 161/240, Train_loss: 0.9111 Train_dice: 0.0889
# 162/240, Train_loss: 0.9791 Train_dice: 0.0209
# 163/240, Train_loss: 0.9903 Train_dice: 0.0097
# 164/240, Train_loss: 0.9692 Train_dice: 0.0308
# 165/240, Train_loss: 0.9961 Train_dice: 0.0039
# 166/240, Train_loss: 0.9952 Train_dice: 0.0048
# 167/240, Train_loss: 0.9919 Train_dice: 0.0081
# 168/240, Train_loss: 0.9951 Train_dice: 0.0049
# 169/240, Train_loss: 0.9989 Train_dice: 0.0011
# 170/240, Train_loss: 0.9907 Train_dice: 0.0093
# 171/240, Train_loss: 0.9898 Train_dice: 0.0102
# 172/240, Train_loss: 0.9894 Train_dice: 0.0106
# 173/240, Train_loss: 0.9965 Train_dice: 0.0035
# 174/240, Train_loss: 0.9946 Train_dice: 0.0054
# 175/240, Train_loss: 0.9842 Train_dice: 0.0158
# 176/240, Train_loss: 0.9944 Train_dice: 0.0056
# 177/240, Train_loss: 0.9722 Train_dice: 0.0278
# 178/240, Train_loss: 0.9939 Train_dice: 0.0061
# 179/240, Train_loss: 0.9927 Train_dice: 0.0073
# 180/240, Train_loss: 0.9853 Train_dice: 0.0147
# 181/240, Train_loss: 0.9920 Train_dice: 0.0080
# 182/240, Train_loss: 0.9955 Train_dice: 0.0045
# 183/240, Train_loss: 0.9901 Train_dice: 0.0099
# 184/240, Train_loss: 0.9665 Train_dice: 0.0335
# 185/240, Train_loss: 0.9923 Train_dice: 0.0077
# 186/240, Train_loss: 0.9811 Train_dice: 0.0189
# 187/240, Train_loss: 0.9863 Train_dice: 0.0137
# 188/240, Train_loss: 0.9956 Train_dice: 0.0044
# 189/240, Train_loss: 0.9452 Train_dice: 0.0548
# 190/240, Train_loss: 0.9993 Train_dice: 0.0007
# 191/240, Train_loss: 0.9783 Train_dice: 0.0217
# 192/240, Train_loss: 0.9889 Train_dice: 0.0111
# 193/240, Train_loss: 0.9917 Train_dice: 0.0083
# 194/240, Train_loss: 0.9940 Train_dice: 0.0060
# 195/240, Train_loss: 0.9922 Train_dice: 0.0078
# 196/240, Train_loss: 0.9932 Train_dice: 0.0068
# 197/240, Train_loss: 0.9885 Train_dice: 0.0115
# 198/240, Train_loss: 0.9972 Train_dice: 0.0028
# 199/240, Train_loss: 0.9987 Train_dice: 0.0013
# 200/240, Train_loss: 0.9369 Train_dice: 0.0631
# 201/240, Train_loss: 0.9949 Train_dice: 0.0051
# 202/240, Train_loss: 0.9959 Train_dice: 0.0041
# 203/240, Train_loss: 0.9805 Train_dice: 0.0195
# 204/240, Train_loss: 0.9950 Train_dice: 0.0050
# 205/240, Train_loss: 0.9939 Train_dice: 0.0061
# 206/240, Train_loss: 0.9905 Train_dice: 0.0095
# 207/240, Train_loss: 0.9987 Train_dice: 0.0013
# 208/240, Train_loss: 0.9989 Train_dice: 0.0011
# 209/240, Train_loss: 0.9874 Train_dice: 0.0126
# 210/240, Train_loss: 0.9826 Train_dice: 0.0174
# 211/240, Train_loss: 0.9957 Train_dice: 0.0043
# 212/240, Train_loss: 0.9921 Train_dice: 0.0079
# 213/240, Train_loss: 0.9916 Train_dice: 0.0084
# 214/240, Train_loss: 0.9512 Train_dice: 0.0488
# 215/240, Train_loss: 0.9890 Train_dice: 0.0110
# 216/240, Train_loss: 0.9899 Train_dice: 0.0101
# 217/240, Train_loss: 0.9832 Train_dice: 0.0168
# 218/240, Train_loss: 0.9434 Train_dice: 0.0566
# 219/240, Train_loss: 0.9932 Train_dice: 0.0068
# 220/240, Train_loss: 0.9619 Train_dice: 0.0381
# 221/240, Train_loss: 0.9629 Train_dice: 0.0371
# 222/240, Train_loss: 0.9916 Train_dice: 0.0084
# 223/240, Train_loss: 0.9951 Train_dice: 0.0049
# 224/240, Train_loss: 0.9939 Train_dice: 0.0061
# 225/240, Train_loss: 0.9855 Train_dice: 0.0145
# 226/240, Train_loss: 0.9822 Train_dice: 0.0178
# 227/240, Train_loss: 0.9670 Train_dice: 0.0330
# 228/240, Train_loss: 0.9925 Train_dice: 0.0075
# 229/240, Train_loss: 0.9968 Train_dice: 0.0032
# 230/240, Train_loss: 0.9906 Train_dice: 0.0094
# 231/240, Train_loss: 0.9609 Train_dice: 0.0391
# 232/240, Train_loss: 0.9864 Train_dice: 0.0136
# 233/240, Train_loss: 0.9925 Train_dice: 0.0075
# 234/240, Train_loss: 0.9849 Train_dice: 0.0151
# 235/240, Train_loss: 0.9811 Train_dice: 0.0189
# 236/240, Train_loss: 0.8923 Train_dice: 0.1077
# 237/240, Train_loss: 0.9798 Train_dice: 0.0202
# 238/240, Train_loss: 0.9845 Train_dice: 0.0155
# 239/240, Train_loss: 0.9686 Train_dice: 0.0314
# 240/240, Train_loss: 0.9946 Train_dice: 0.0054
# --------------------
# Epoch_loss: 0.9853
# Epoch_metric: 0.0147
# ----------
# epoch 2/10
# 1/240, Train_loss: 0.9955 Train_dice: 0.0045
# 2/240, Train_loss: 0.9936 Train_dice: 0.0064
# 3/240, Train_loss: 0.9927 Train_dice: 0.0073
# 4/240, Train_loss: 0.9577 Train_dice: 0.0423
# 5/240, Train_loss: 0.9895 Train_dice: 0.0105
# 6/240, Train_loss: 0.9937 Train_dice: 0.0063
# 7/240, Train_loss: 0.9891 Train_dice: 0.0109
# 8/240, Train_loss: 0.9471 Train_dice: 0.0529
# 9/240, Train_loss: 0.9957 Train_dice: 0.0043
# 10/240, Train_loss: 0.9806 Train_dice: 0.0194
# 11/240, Train_loss: 0.9652 Train_dice: 0.0348
# 12/240, Train_loss: 0.9945 Train_dice: 0.0055
# 13/240, Train_loss: 0.9967 Train_dice: 0.0033
# 14/240, Train_loss: 0.9931 Train_dice: 0.0069
# 15/240, Train_loss: 0.9900 Train_dice: 0.0100
# 16/240, Train_loss: 0.9855 Train_dice: 0.0145
# 17/240, Train_loss: 0.9746 Train_dice: 0.0254
# 18/240, Train_loss: 0.9949 Train_dice: 0.0051
# 19/240, Train_loss: 0.9968 Train_dice: 0.0032
# 20/240, Train_loss: 0.9908 Train_dice: 0.0092
# 21/240, Train_loss: 0.9722 Train_dice: 0.0278
# 22/240, Train_loss: 0.9899 Train_dice: 0.0101
# 23/240, Train_loss: 0.9937 Train_dice: 0.0063
# 24/240, Train_loss: 0.9849 Train_dice: 0.0151
# 25/240, Train_loss: 0.9824 Train_dice: 0.0176
# 26/240, Train_loss: 0.9153 Train_dice: 0.0847
# 27/240, Train_loss: 0.9842 Train_dice: 0.0158
# 28/240, Train_loss: 0.9896 Train_dice: 0.0104
# 29/240, Train_loss: 0.9821 Train_dice: 0.0179
# 30/240, Train_loss: 0.9962 Train_dice: 0.0038
# 31/240, Train_loss: 0.9977 Train_dice: 0.0023
# 32/240, Train_loss: 0.9953 Train_dice: 0.0047
# 33/240, Train_loss: 0.9971 Train_dice: 0.0029
# 34/240, Train_loss: 0.9985 Train_dice: 0.0015
# 35/240, Train_loss: 0.9916 Train_dice: 0.0084
# 36/240, Train_loss: 0.9922 Train_dice: 0.0078
# 37/240, Train_loss: 0.9977 Train_dice: 0.0023
# 38/240, Train_loss: 0.9974 Train_dice: 0.0026
# 39/240, Train_loss: 0.9954 Train_dice: 0.0046
# 40/240, Train_loss: 0.9841 Train_dice: 0.0159
# 41/240, Train_loss: 0.9897 Train_dice: 0.0103
# 42/240, Train_loss: 0.9824 Train_dice: 0.0176
# 43/240, Train_loss: 0.9966 Train_dice: 0.0034
# 44/240, Train_loss: 0.9953 Train_dice: 0.0047
# 45/240, Train_loss: 0.9907 Train_dice: 0.0093
# 46/240, Train_loss: 0.9947 Train_dice: 0.0053
# 47/240, Train_loss: 0.9962 Train_dice: 0.0038
# 48/240, Train_loss: 0.9911 Train_dice: 0.0089
# 49/240, Train_loss: 0.9657 Train_dice: 0.0343
# 50/240, Train_loss: 0.9952 Train_dice: 0.0048
# 51/240, Train_loss: 0.9873 Train_dice: 0.0127
# 52/240, Train_loss: 0.9875 Train_dice: 0.0125
# 53/240, Train_loss: 0.9987 Train_dice: 0.0013
# 54/240, Train_loss: 0.9519 Train_dice: 0.0481
# 55/240, Train_loss: 0.9993 Train_dice: 0.0007
# 56/240, Train_loss: 0.9866 Train_dice: 0.0134
# 57/240, Train_loss: 0.9928 Train_dice: 0.0072
# 58/240, Train_loss: 0.9926 Train_dice: 0.0074
# 59/240, Train_loss: 0.9941 Train_dice: 0.0059
# 60/240, Train_loss: 0.9924 Train_dice: 0.0076
# 61/240, Train_loss: 0.9925 Train_dice: 0.0075
# 62/240, Train_loss: 0.9916 Train_dice: 0.0084
# 63/240, Train_loss: 0.9873 Train_dice: 0.0127
# 64/240, Train_loss: 0.9455 Train_dice: 0.0545
# 65/240, Train_loss: 0.9874 Train_dice: 0.0126
# 66/240, Train_loss: 0.9921 Train_dice: 0.0079
# 67/240, Train_loss: 0.9795 Train_dice: 0.0205
# 68/240, Train_loss: 0.9515 Train_dice: 0.0485
# 69/240, Train_loss: 0.9936 Train_dice: 0.0064
# 70/240, Train_loss: 0.9764 Train_dice: 0.0236
# 71/240, Train_loss: 0.9520 Train_dice: 0.0480
# 72/240, Train_loss: 0.9913 Train_dice: 0.0087
# 73/240, Train_loss: 0.9968 Train_dice: 0.0032
# 74/240, Train_loss: 0.9929 Train_dice: 0.0071
# 75/240, Train_loss: 0.9840 Train_dice: 0.0160
# 76/240, Train_loss: 0.9780 Train_dice: 0.0220
# 77/240, Train_loss: 0.9653 Train_dice: 0.0347
# 78/240, Train_loss: 0.9951 Train_dice: 0.0049
# 79/240, Train_loss: 0.9943 Train_dice: 0.0057
# 80/240, Train_loss: 0.9857 Train_dice: 0.0143
# 81/240, Train_loss: 0.9654 Train_dice: 0.0346
# 82/240, Train_loss: 0.9853 Train_dice: 0.0147
# 83/240, Train_loss: 0.9906 Train_dice: 0.0094
# 84/240, Train_loss: 0.9844 Train_dice: 0.0156
# 85/240, Train_loss: 0.9769 Train_dice: 0.0231
# 86/240, Train_loss: 0.8885 Train_dice: 0.1115
# 87/240, Train_loss: 0.9798 Train_dice: 0.0202
# 88/240, Train_loss: 0.9839 Train_dice: 0.0161
# 89/240, Train_loss: 0.9666 Train_dice: 0.0334
# 90/240, Train_loss: 0.9945 Train_dice: 0.0055
# 91/240, Train_loss: 0.9968 Train_dice: 0.0032
# 92/240, Train_loss: 0.9912 Train_dice: 0.0088
# 93/240, Train_loss: 0.9947 Train_dice: 0.0053
# 94/240, Train_loss: 0.9985 Train_dice: 0.0015
# 95/240, Train_loss: 0.9877 Train_dice: 0.0123
# 96/240, Train_loss: 0.9871 Train_dice: 0.0129
# 97/240, Train_loss: 0.9885 Train_dice: 0.0115
# 98/240, Train_loss: 0.9957 Train_dice: 0.0043
# 99/240, Train_loss: 0.9933 Train_dice: 0.0067
# 100/240, Train_loss: 0.9847 Train_dice: 0.0153
# 101/240, Train_loss: 0.9897 Train_dice: 0.0103
# 102/240, Train_loss: 0.9770 Train_dice: 0.0230
# 103/240, Train_loss: 0.9951 Train_dice: 0.0049
# 104/240, Train_loss: 0.9955 Train_dice: 0.0045
# 105/240, Train_loss: 0.9816 Train_dice: 0.0184
# 106/240, Train_loss: 0.9929 Train_dice: 0.0071
# 107/240, Train_loss: 0.9953 Train_dice: 0.0047
# 108/240, Train_loss: 0.9845 Train_dice: 0.0155
# 109/240, Train_loss: 0.9577 Train_dice: 0.0423
# 110/240, Train_loss: 0.9936 Train_dice: 0.0064
# 111/240, Train_loss: 0.9794 Train_dice: 0.0206
# 112/240, Train_loss: 0.9856 Train_dice: 0.0144
# 113/240, Train_loss: 0.9938 Train_dice: 0.0062
# 114/240, Train_loss: 0.9483 Train_dice: 0.0517
# 115/240, Train_loss: 0.9988 Train_dice: 0.0012
# 116/240, Train_loss: 0.9859 Train_dice: 0.0141
# 117/240, Train_loss: 0.9871 Train_dice: 0.0129
# 118/240, Train_loss: 0.9902 Train_dice: 0.0098
# 119/240, Train_loss: 0.9899 Train_dice: 0.0101
# 120/240, Train_loss: 0.9907 Train_dice: 0.0093
# 121/240, Train_loss: 0.9963 Train_dice: 0.0037
# 122/240, Train_loss: 0.9774 Train_dice: 0.0226
# 123/240, Train_loss: 0.9933 Train_dice: 0.0067
# 124/240, Train_loss: 0.9958 Train_dice: 0.0042
# 125/240, Train_loss: 0.9366 Train_dice: 0.0634
# 126/240, Train_loss: 0.9934 Train_dice: 0.0066
# 127/240, Train_loss: 0.9954 Train_dice: 0.0046
# 128/240, Train_loss: 0.9884 Train_dice: 0.0116
# 129/240, Train_loss: 0.9979 Train_dice: 0.0021
# 130/240, Train_loss: 0.9858 Train_dice: 0.0142
# 131/240, Train_loss: 0.9854 Train_dice: 0.0146
# 132/240, Train_loss: 1.0000 Train_dice: 0.0000
# 133/240, Train_loss: 0.9995 Train_dice: 0.0005
# 134/240, Train_loss: 0.9887 Train_dice: 0.0113
# 135/240, Train_loss: 0.9852 Train_dice: 0.0148
# 136/240, Train_loss: 0.9920 Train_dice: 0.0080
# 137/240, Train_loss: 0.9876 Train_dice: 0.0124
# 138/240, Train_loss: 0.9907 Train_dice: 0.0093
# 139/240, Train_loss: 0.9440 Train_dice: 0.0560
# 140/240, Train_loss: 0.9884 Train_dice: 0.0116
# 141/240, Train_loss: 0.9932 Train_dice: 0.0068
# 142/240, Train_loss: 0.9882 Train_dice: 0.0118
# 143/240, Train_loss: 0.9270 Train_dice: 0.0730
# 144/240, Train_loss: 0.9930 Train_dice: 0.0070
# 145/240, Train_loss: 0.9567 Train_dice: 0.0433
# 146/240, Train_loss: 0.9515 Train_dice: 0.0485
# 147/240, Train_loss: 0.9939 Train_dice: 0.0061
# 148/240, Train_loss: 0.9941 Train_dice: 0.0059
# 149/240, Train_loss: 0.9915 Train_dice: 0.0085
# 150/240, Train_loss: 0.9834 Train_dice: 0.0166
# 151/240, Train_loss: 0.9793 Train_dice: 0.0207
# 152/240, Train_loss: 0.9627 Train_dice: 0.0373
# 153/240, Train_loss: 0.9904 Train_dice: 0.0096
# 154/240, Train_loss: 0.9937 Train_dice: 0.0063
# 155/240, Train_loss: 0.9870 Train_dice: 0.0130
# 156/240, Train_loss: 0.9560 Train_dice: 0.0440
# 157/240, Train_loss: 0.9840 Train_dice: 0.0160
# 158/240, Train_loss: 0.9904 Train_dice: 0.0096
# 159/240, Train_loss: 0.9753 Train_dice: 0.0247
# 160/240, Train_loss: 0.9865 Train_dice: 0.0135
# 161/240, Train_loss: 0.9004 Train_dice: 0.0996
# 162/240, Train_loss: 0.9769 Train_dice: 0.0231
# 163/240, Train_loss: 0.9891 Train_dice: 0.0109
# 164/240, Train_loss: 0.9653 Train_dice: 0.0347
# 165/240, Train_loss: 0.9956 Train_dice: 0.0044
# 166/240, Train_loss: 0.9947 Train_dice: 0.0053
# 167/240, Train_loss: 0.9909 Train_dice: 0.0091
# 168/240, Train_loss: 0.9945 Train_dice: 0.0055
# 169/240, Train_loss: 0.9987 Train_dice: 0.0013
# 170/240, Train_loss: 0.9896 Train_dice: 0.0104
# 171/240, Train_loss: 0.9885 Train_dice: 0.0115
# 172/240, Train_loss: 0.9882 Train_dice: 0.0118
# 173/240, Train_loss: 0.9960 Train_dice: 0.0040
# 174/240, Train_loss: 0.9958 Train_dice: 0.0042
# 175/240, Train_loss: 0.9823 Train_dice: 0.0177
# 176/240, Train_loss: 0.9935 Train_dice: 0.0065
# 177/240, Train_loss: 0.9693 Train_dice: 0.0307
# 178/240, Train_loss: 0.9931 Train_dice: 0.0069
# 179/240, Train_loss: 0.9916 Train_dice: 0.0084
# 180/240, Train_loss: 0.9842 Train_dice: 0.0158
# 181/240, Train_loss: 0.9908 Train_dice: 0.0092
# 182/240, Train_loss: 0.9950 Train_dice: 0.0050
# 183/240, Train_loss: 0.9889 Train_dice: 0.0111
# 184/240, Train_loss: 0.9627 Train_dice: 0.0373
# 185/240, Train_loss: 0.9914 Train_dice: 0.0086
# 186/240, Train_loss: 0.9787 Train_dice: 0.0213
# 187/240, Train_loss: 0.9825 Train_dice: 0.0175
# 188/240, Train_loss: 0.9984 Train_dice: 0.0016
# 189/240, Train_loss: 0.9425 Train_dice: 0.0575
# 190/240, Train_loss: 0.9992 Train_dice: 0.0008
# 191/240, Train_loss: 0.9746 Train_dice: 0.0254
# 192/240, Train_loss: 0.9878 Train_dice: 0.0122
# 193/240, Train_loss: 0.9909 Train_dice: 0.0091
# 194/240, Train_loss: 0.9934 Train_dice: 0.0066
# 195/240, Train_loss: 0.9908 Train_dice: 0.0092
# 196/240, Train_loss: 0.9933 Train_dice: 0.0067
# 197/240, Train_loss: 0.9824 Train_dice: 0.0176
# 198/240, Train_loss: 0.9969 Train_dice: 0.0031
# 199/240, Train_loss: 0.9956 Train_dice: 0.0044
# 200/240, Train_loss: 0.9309 Train_dice: 0.0691
# 201/240, Train_loss: 0.9931 Train_dice: 0.0069
# 202/240, Train_loss: 0.9954 Train_dice: 0.0046
# 203/240, Train_loss: 0.9793 Train_dice: 0.0207
# 204/240, Train_loss: 0.9936 Train_dice: 0.0064
# 205/240, Train_loss: 0.9935 Train_dice: 0.0065
# 206/240, Train_loss: 0.9893 Train_dice: 0.0107
# 207/240, Train_loss: 0.9985 Train_dice: 0.0015
# 208/240, Train_loss: 0.9987 Train_dice: 0.0013
# 209/240, Train_loss: 0.9856 Train_dice: 0.0144
# 210/240, Train_loss: 0.9804 Train_dice: 0.0196
# 211/240, Train_loss: 0.9952 Train_dice: 0.0048
# 212/240, Train_loss: 0.9911 Train_dice: 0.0089
# 213/240, Train_loss: 0.9905 Train_dice: 0.0095
# 214/240, Train_loss: 0.9438 Train_dice: 0.0562
# 215/240, Train_loss: 0.9876 Train_dice: 0.0124
# 216/240, Train_loss: 0.9892 Train_dice: 0.0108
# 217/240, Train_loss: 0.9810 Train_dice: 0.0190
# 218/240, Train_loss: 0.9344 Train_dice: 0.0656
# 219/240, Train_loss: 0.9922 Train_dice: 0.0078
# 220/240, Train_loss: 0.9572 Train_dice: 0.0428
# 221/240, Train_loss: 0.9585 Train_dice: 0.0415
# 222/240, Train_loss: 0.9906 Train_dice: 0.0094
# 223/240, Train_loss: 0.9946 Train_dice: 0.0054
# 224/240, Train_loss: 0.9914 Train_dice: 0.0086
# 225/240, Train_loss: 0.9837 Train_dice: 0.0163
# 226/240, Train_loss: 0.9807 Train_dice: 0.0193
# 227/240, Train_loss: 0.9630 Train_dice: 0.0370
# 228/240, Train_loss: 0.9915 Train_dice: 0.0085
# 229/240, Train_loss: 0.9964 Train_dice: 0.0036
# 230/240, Train_loss: 0.9895 Train_dice: 0.0105
# 231/240, Train_loss: 0.9559 Train_dice: 0.0441
# 232/240, Train_loss: 0.9846 Train_dice: 0.0154
# 233/240, Train_loss: 0.9916 Train_dice: 0.0084
# 234/240, Train_loss: 0.9830 Train_dice: 0.0170
# 235/240, Train_loss: 0.9782 Train_dice: 0.0218
# 236/240, Train_loss: 0.8784 Train_dice: 0.1216
# 237/240, Train_loss: 0.9774 Train_dice: 0.0226
# 238/240, Train_loss: 0.9830 Train_dice: 0.0170
# 239/240, Train_loss: 0.9644 Train_dice: 0.0356
# 240/240, Train_loss: 0.9939 Train_dice: 0.0061
# --------------------
# Epoch_loss: 0.9836
# Epoch_metric: 0.0164
# test_loss_epoch: 0.9896
# test_dice_epoch: 0.0113
# current epoch: 2 current mean dice: 0.0126
# best mean dice: 0.0113 at epoch: 2
# Time Taken:  2254.474479198456
# Maximum GPU Memory taken for training:  0
# Maximum CPU Memory taken for training:  0
# train completed, best_metric: 0.0113 at epoch: 2
# ----------
# epoch 3/10
# 1/240, Train_loss: 0.9949 Train_dice: 0.0051
# 2/240, Train_loss: 0.9928 Train_dice: 0.0072
# 3/240, Train_loss: 0.9917 Train_dice: 0.0083
# 4/240, Train_loss: 0.9524 Train_dice: 0.0476
# 5/240, Train_loss: 0.9881 Train_dice: 0.0119
# 6/240, Train_loss: 0.9928 Train_dice: 0.0072
# 7/240, Train_loss: 0.9876 Train_dice: 0.0124
# 8/240, Train_loss: 0.9402 Train_dice: 0.0598
# 9/240, Train_loss: 0.9951 Train_dice: 0.0049
# 10/240, Train_loss: 0.9780 Train_dice: 0.0220
# 11/240, Train_loss: 0.9608 Train_dice: 0.0392
# 12/240, Train_loss: 0.9938 Train_dice: 0.0062
# 13/240, Train_loss: 0.9962 Train_dice: 0.0038
# 14/240, Train_loss: 0.9921 Train_dice: 0.0079
# 15/240, Train_loss: 0.9886 Train_dice: 0.0114
# 16/240, Train_loss: 0.9840 Train_dice: 0.0160
# 17/240, Train_loss: 0.9712 Train_dice: 0.0288
# 18/240, Train_loss: 0.9942 Train_dice: 0.0058
# 19/240, Train_loss: 0.9964 Train_dice: 0.0036
# 20/240, Train_loss: 0.9895 Train_dice: 0.0105
# 21/240, Train_loss: 0.9685 Train_dice: 0.0315
# 22/240, Train_loss: 0.9885 Train_dice: 0.0115
# 23/240, Train_loss: 0.9928 Train_dice: 0.0072
# 24/240, Train_loss: 0.9829 Train_dice: 0.0171
# 25/240, Train_loss: 0.9802 Train_dice: 0.0198
# 26/240, Train_loss: 0.9038 Train_dice: 0.0962
# 27/240, Train_loss: 0.9823 Train_dice: 0.0177
# 28/240, Train_loss: 0.9882 Train_dice: 0.0118
# 29/240, Train_loss: 0.9796 Train_dice: 0.0204
# 30/240, Train_loss: 0.9957 Train_dice: 0.0043
# 31/240, Train_loss: 0.9974 Train_dice: 0.0026
# 32/240, Train_loss: 0.9948 Train_dice: 0.0052
# 33/240, Train_loss: 0.9967 Train_dice: 0.0033
# 34/240, Train_loss: 0.9983 Train_dice: 0.0017
# 35/240, Train_loss: 0.9905 Train_dice: 0.0095
# 36/240, Train_loss: 0.9911 Train_dice: 0.0089
# 37/240, Train_loss: 0.9976 Train_dice: 0.0024
# 38/240, Train_loss: 0.9971 Train_dice: 0.0029
# 39/240, Train_loss: 0.9948 Train_dice: 0.0052
# 40/240, Train_loss: 0.9821 Train_dice: 0.0179
# 41/240, Train_loss: 0.9886 Train_dice: 0.0114
# 42/240, Train_loss: 0.9803 Train_dice: 0.0197
# 43/240, Train_loss: 0.9961 Train_dice: 0.0039
# 44/240, Train_loss: 0.9950 Train_dice: 0.0050
# 45/240, Train_loss: 0.9869 Train_dice: 0.0131
# 46/240, Train_loss: 0.9937 Train_dice: 0.0063
# 47/240, Train_loss: 0.9956 Train_dice: 0.0044
# 48/240, Train_loss: 0.9900 Train_dice: 0.0100
# 49/240, Train_loss: 0.9627 Train_dice: 0.0373
# 50/240, Train_loss: 0.9946 Train_dice: 0.0054
# 51/240, Train_loss: 0.9852 Train_dice: 0.0148
# 52/240, Train_loss: 0.9883 Train_dice: 0.0117
# 53/240, Train_loss: 0.9959 Train_dice: 0.0041
# 54/240, Train_loss: 0.9460 Train_dice: 0.0540
# 55/240, Train_loss: 0.9992 Train_dice: 0.0008
# 56/240, Train_loss: 0.9851 Train_dice: 0.0149
# 57/240, Train_loss: 0.9917 Train_dice: 0.0083
# 58/240, Train_loss: 0.9916 Train_dice: 0.0084
# 59/240, Train_loss: 0.9932 Train_dice: 0.0068
# 60/240, Train_loss: 0.9921 Train_dice: 0.0079
# 61/240, Train_loss: 0.9915 Train_dice: 0.0085
# 62/240, Train_loss: 0.9904 Train_dice: 0.0096
# 63/240, Train_loss: 0.9854 Train_dice: 0.0146
# 64/240, Train_loss: 0.9431 Train_dice: 0.0569
# 65/240, Train_loss: 0.9856 Train_dice: 0.0144
# 66/240, Train_loss: 0.9910 Train_dice: 0.0090
# 67/240, Train_loss: 0.9764 Train_dice: 0.0236
# 68/240, Train_loss: 0.9303 Train_dice: 0.0697
# 69/240, Train_loss: 0.9929 Train_dice: 0.0071
# 70/240, Train_loss: 0.9731 Train_dice: 0.0269
# 71/240, Train_loss: 0.9457 Train_dice: 0.0543
# 72/240, Train_loss: 0.9904 Train_dice: 0.0096
# 73/240, Train_loss: 0.9966 Train_dice: 0.0034
# 74/240, Train_loss: 0.9928 Train_dice: 0.0072
# 75/240, Train_loss: 0.9817 Train_dice: 0.0183
# 76/240, Train_loss: 0.9752 Train_dice: 0.0248
# 77/240, Train_loss: 0.9607 Train_dice: 0.0393
# 78/240, Train_loss: 0.9944 Train_dice: 0.0056
# 79/240, Train_loss: 0.9936 Train_dice: 0.0064
# 80/240, Train_loss: 0.9840 Train_dice: 0.0160
# 81/240, Train_loss: 0.9613 Train_dice: 0.0387
# 82/240, Train_loss: 0.9850 Train_dice: 0.0150
# 83/240, Train_loss: 0.9895 Train_dice: 0.0105
# 84/240, Train_loss: 0.9820 Train_dice: 0.0180
# 85/240, Train_loss: 0.9733 Train_dice: 0.0267
# 86/240, Train_loss: 0.8708 Train_dice: 0.1292
# 87/240, Train_loss: 0.9776 Train_dice: 0.0224
# 88/240, Train_loss: 0.9819 Train_dice: 0.0181
# 89/240, Train_loss: 0.9622 Train_dice: 0.0378
# 90/240, Train_loss: 0.9937 Train_dice: 0.0063
# 91/240, Train_loss: 0.9964 Train_dice: 0.0036
# 92/240, Train_loss: 0.9899 Train_dice: 0.0101
# 93/240, Train_loss: 0.9940 Train_dice: 0.0060
# 94/240, Train_loss: 0.9984 Train_dice: 0.0016
# 95/240, Train_loss: 0.9861 Train_dice: 0.0139
# 96/240, Train_loss: 0.9854 Train_dice: 0.0146
# 97/240, Train_loss: 0.9870 Train_dice: 0.0130
# 98/240, Train_loss: 0.9952 Train_dice: 0.0048
# 99/240, Train_loss: 0.9926 Train_dice: 0.0074
# 100/240, Train_loss: 0.9827 Train_dice: 0.0173
# 101/240, Train_loss: 0.9875 Train_dice: 0.0125
# 102/240, Train_loss: 0.9708 Train_dice: 0.0292
# 103/240, Train_loss: 0.9943 Train_dice: 0.0057
# 104/240, Train_loss: 0.9945 Train_dice: 0.0055
# 105/240, Train_loss: 0.9829 Train_dice: 0.0171
# 106/240, Train_loss: 0.9918 Train_dice: 0.0082
# 107/240, Train_loss: 0.9947 Train_dice: 0.0053
# 108/240, Train_loss: 0.9823 Train_dice: 0.0177
# 109/240, Train_loss: 0.9508 Train_dice: 0.0492
# 110/240, Train_loss: 0.9926 Train_dice: 0.0074
# 111/240, Train_loss: 0.9774 Train_dice: 0.0226
# 112/240, Train_loss: 0.9799 Train_dice: 0.0201
# 113/240, Train_loss: 0.9975 Train_dice: 0.0025
# 114/240, Train_loss: 0.9423 Train_dice: 0.0577
# 115/240, Train_loss: 0.9986 Train_dice: 0.0014
# 116/240, Train_loss: 0.9844 Train_dice: 0.0156
# 117/240, Train_loss: 0.9856 Train_dice: 0.0144
# 118/240, Train_loss: 0.9893 Train_dice: 0.0107
# 119/240, Train_loss: 0.9888 Train_dice: 0.0112
# 120/240, Train_loss: 0.9894 Train_dice: 0.0106
# 121/240, Train_loss: 0.9960 Train_dice: 0.0040
# 122/240, Train_loss: 0.9716 Train_dice: 0.0284
# 123/240, Train_loss: 0.9927 Train_dice: 0.0073
# 124/240, Train_loss: 0.9949 Train_dice: 0.0051
# 125/240, Train_loss: 0.9305 Train_dice: 0.0695
# 126/240, Train_loss: 0.9923 Train_dice: 0.0077
# 127/240, Train_loss: 0.9947 Train_dice: 0.0053
# 128/240, Train_loss: 0.9870 Train_dice: 0.0130
# 129/240, Train_loss: 0.9978 Train_dice: 0.0022
# 130/240, Train_loss: 0.9838 Train_dice: 0.0162
# 131/240, Train_loss: 0.9833 Train_dice: 0.0167
# 132/240, Train_loss: 1.0000 Train_dice: 0.0000
# 133/240, Train_loss: 0.9996 Train_dice: 0.0004
# 134/240, Train_loss: 0.9880 Train_dice: 0.0120
# 135/240, Train_loss: 0.9833 Train_dice: 0.0167
# 136/240, Train_loss: 0.9908 Train_dice: 0.0092
# 137/240, Train_loss: 0.9857 Train_dice: 0.0143
# 138/240, Train_loss: 0.9891 Train_dice: 0.0109
# 139/240, Train_loss: 0.9347 Train_dice: 0.0653
# 140/240, Train_loss: 0.9865 Train_dice: 0.0135
# 141/240, Train_loss: 0.9922 Train_dice: 0.0078
# 142/240, Train_loss: 0.9864 Train_dice: 0.0136
# 143/240, Train_loss: 0.9196 Train_dice: 0.0804
# 144/240, Train_loss: 0.9917 Train_dice: 0.0083
# 145/240, Train_loss: 0.9497 Train_dice: 0.0503
# 146/240, Train_loss: 0.9446 Train_dice: 0.0554
# 147/240, Train_loss: 0.9929 Train_dice: 0.0071
# 148/240, Train_loss: 0.9935 Train_dice: 0.0065
# 149/240, Train_loss: 0.9896 Train_dice: 0.0104
# 150/240, Train_loss: 0.9809 Train_dice: 0.0191
# 151/240, Train_loss: 0.9781 Train_dice: 0.0219
# 152/240, Train_loss: 0.9576 Train_dice: 0.0424
# 153/240, Train_loss: 0.9890 Train_dice: 0.0110
# 154/240, Train_loss: 0.9929 Train_dice: 0.0071
# 155/240, Train_loss: 0.9853 Train_dice: 0.0147
# 156/240, Train_loss: 0.9509 Train_dice: 0.0491
# 157/240, Train_loss: 0.9817 Train_dice: 0.0183
# 158/240, Train_loss: 0.9890 Train_dice: 0.0110
# 159/240, Train_loss: 0.9721 Train_dice: 0.0279
# 160/240, Train_loss: 0.9821 Train_dice: 0.0179
# 161/240, Train_loss: 0.8866 Train_dice: 0.1134
# 162/240, Train_loss: 0.9732 Train_dice: 0.0268
# 163/240, Train_loss: 0.9880 Train_dice: 0.0120
# 164/240, Train_loss: 0.9607 Train_dice: 0.0393
# 165/240, Train_loss: 0.9950 Train_dice: 0.0050
# 166/240, Train_loss: 0.9946 Train_dice: 0.0054
# 167/240, Train_loss: 0.9898 Train_dice: 0.0102
# 168/240, Train_loss: 0.9939 Train_dice: 0.0061
# 169/240, Train_loss: 0.9987 Train_dice: 0.0013
# 170/240, Train_loss: 0.9883 Train_dice: 0.0117
# 171/240, Train_loss: 0.9871 Train_dice: 0.0129
# 172/240, Train_loss: 0.9869 Train_dice: 0.0131
# 173/240, Train_loss: 0.9956 Train_dice: 0.0044
# 174/240, Train_loss: 0.9927 Train_dice: 0.0073
# 175/240, Train_loss: 0.9800 Train_dice: 0.0200
# 176/240, Train_loss: 0.9920 Train_dice: 0.0080
# 177/240, Train_loss: 0.9652 Train_dice: 0.0348
# 178/240, Train_loss: 0.9922 Train_dice: 0.0078
# 179/240, Train_loss: 0.9907 Train_dice: 0.0093
# 180/240, Train_loss: 0.9793 Train_dice: 0.0207
# 181/240, Train_loss: 0.9896 Train_dice: 0.0104
# 182/240, Train_loss: 0.9942 Train_dice: 0.0058
# 183/240, Train_loss: 0.9875 Train_dice: 0.0125
# 184/240, Train_loss: 0.9574 Train_dice: 0.0426
# 185/240, Train_loss: 0.9903 Train_dice: 0.0097
# 186/240, Train_loss: 0.9754 Train_dice: 0.0246
# 187/240, Train_loss: 0.9826 Train_dice: 0.0174
# 188/240, Train_loss: 0.9944 Train_dice: 0.0056
# 189/240, Train_loss: 0.9317 Train_dice: 0.0683
# 190/240, Train_loss: 0.9991 Train_dice: 0.0009
# 191/240, Train_loss: 0.9714 Train_dice: 0.0286
# 192/240, Train_loss: 0.9861 Train_dice: 0.0139
# 193/240, Train_loss: 0.9892 Train_dice: 0.0108
# 194/240, Train_loss: 0.9924 Train_dice: 0.0076
# 195/240, Train_loss: 0.9898 Train_dice: 0.0102
# 196/240, Train_loss: 0.9915 Train_dice: 0.0085
# 197/240, Train_loss: 0.9796 Train_dice: 0.0204
# 198/240, Train_loss: 0.9964 Train_dice: 0.0036
# 199/240, Train_loss: 0.9978 Train_dice: 0.0022
# 200/240, Train_loss: 0.9187 Train_dice: 0.0813
# 201/240, Train_loss: 0.9929 Train_dice: 0.0071
# 202/240, Train_loss: 0.9947 Train_dice: 0.0053
# 203/240, Train_loss: 0.9748 Train_dice: 0.0252
# 204/240, Train_loss: 0.9931 Train_dice: 0.0069
# 205/240, Train_loss: 0.9934 Train_dice: 0.0066
# 206/240, Train_loss: 0.9878 Train_dice: 0.0122
# 207/240, Train_loss: 0.9983 Train_dice: 0.0017
# 208/240, Train_loss: 0.9985 Train_dice: 0.0015
# 209/240, Train_loss: 0.9840 Train_dice: 0.0160
# 210/240, Train_loss: 0.9779 Train_dice: 0.0221
# 211/240, Train_loss: 0.9946 Train_dice: 0.0054
# 212/240, Train_loss: 0.9897 Train_dice: 0.0103
# 213/240, Train_loss: 0.9890 Train_dice: 0.0110
# 214/240, Train_loss: 0.9371 Train_dice: 0.0629
# 215/240, Train_loss: 0.9856 Train_dice: 0.0144
# 216/240, Train_loss: 0.9877 Train_dice: 0.0123
# 217/240, Train_loss: 0.9782 Train_dice: 0.0218
# 218/240, Train_loss: 0.9208 Train_dice: 0.0792
# 219/240, Train_loss: 0.9916 Train_dice: 0.0084
# 220/240, Train_loss: 0.9519 Train_dice: 0.0481
# 221/240, Train_loss: 0.9522 Train_dice: 0.0478
# 222/240, Train_loss: 0.9892 Train_dice: 0.0108
# 223/240, Train_loss: 0.9934 Train_dice: 0.0066
# 224/240, Train_loss: 0.9910 Train_dice: 0.0090
# 225/240, Train_loss: 0.9811 Train_dice: 0.0189
# 226/240, Train_loss: 0.9778 Train_dice: 0.0222
# 227/240, Train_loss: 0.9579 Train_dice: 0.0421
# 228/240, Train_loss: 0.9904 Train_dice: 0.0096
# 229/240, Train_loss: 0.9959 Train_dice: 0.0041
# 230/240, Train_loss: 0.9880 Train_dice: 0.0120
# 231/240, Train_loss: 0.9507 Train_dice: 0.0493
# 232/240, Train_loss: 0.9826 Train_dice: 0.0174
# 233/240, Train_loss: 0.9902 Train_dice: 0.0098
# 234/240, Train_loss: 0.9803 Train_dice: 0.0197
# 235/240, Train_loss: 0.9755 Train_dice: 0.0245
# 236/240, Train_loss: 0.8599 Train_dice: 0.1401
# 237/240, Train_loss: 0.9745 Train_dice: 0.0255
# 238/240, Train_loss: 0.9810 Train_dice: 0.0190
# 239/240, Train_loss: 0.9589 Train_dice: 0.0411
# 240/240, Train_loss: 0.9929 Train_dice: 0.0071
# --------------------
# Epoch_loss: 0.9813
# Epoch_metric: 0.0187
# ----------
# epoch 4/10
# 1/240, Train_loss: 0.9942 Train_dice: 0.0058
# 2/240, Train_loss: 0.9916 Train_dice: 0.0084
# 3/240, Train_loss: 0.9903 Train_dice: 0.0097
# 4/240, Train_loss: 0.9460 Train_dice: 0.0540
# 5/240, Train_loss: 0.9861 Train_dice: 0.0139
# 6/240, Train_loss: 0.9918 Train_dice: 0.0082
# 7/240, Train_loss: 0.9857 Train_dice: 0.0143
# 8/240, Train_loss: 0.9317 Train_dice: 0.0683
# 9/240, Train_loss: 0.9944 Train_dice: 0.0056
# 10/240, Train_loss: 0.9748 Train_dice: 0.0252
# 11/240, Train_loss: 0.9549 Train_dice: 0.0451
# 12/240, Train_loss: 0.9928 Train_dice: 0.0072
# 13/240, Train_loss: 0.9957 Train_dice: 0.0043
# 14/240, Train_loss: 0.9908 Train_dice: 0.0092
# 15/240, Train_loss: 0.9868 Train_dice: 0.0132
# 16/240, Train_loss: 0.9816 Train_dice: 0.0184
# 17/240, Train_loss: 0.9668 Train_dice: 0.0332
# 18/240, Train_loss: 0.9933 Train_dice: 0.0067
# 19/240, Train_loss: 0.9958 Train_dice: 0.0042
# 20/240, Train_loss: 0.9879 Train_dice: 0.0121
# 21/240, Train_loss: 0.9636 Train_dice: 0.0364
# 22/240, Train_loss: 0.9869 Train_dice: 0.0131
# 23/240, Train_loss: 0.9917 Train_dice: 0.0083
# 24/240, Train_loss: 0.9801 Train_dice: 0.0199
# 25/240, Train_loss: 0.9769 Train_dice: 0.0231
# 26/240, Train_loss: 0.8880 Train_dice: 0.1120
# 27/240, Train_loss: 0.9796 Train_dice: 0.0204
# 28/240, Train_loss: 0.9863 Train_dice: 0.0137
# 29/240, Train_loss: 0.9762 Train_dice: 0.0238
# 30/240, Train_loss: 0.9949 Train_dice: 0.0051
# 31/240, Train_loss: 0.9969 Train_dice: 0.0031
# 32/240, Train_loss: 0.9937 Train_dice: 0.0063
# 33/240, Train_loss: 0.9962 Train_dice: 0.0038
# 34/240, Train_loss: 0.9980 Train_dice: 0.0020
# 35/240, Train_loss: 0.9888 Train_dice: 0.0112
# 36/240, Train_loss: 0.9896 Train_dice: 0.0104
# 37/240, Train_loss: 0.9975 Train_dice: 0.0025
# 38/240, Train_loss: 0.9965 Train_dice: 0.0035
# 39/240, Train_loss: 0.9942 Train_dice: 0.0058
# 40/240, Train_loss: 0.9792 Train_dice: 0.0208
# 41/240, Train_loss: 0.9904 Train_dice: 0.0096
# 42/240, Train_loss: 0.9771 Train_dice: 0.0229
# 43/240, Train_loss: 0.9955 Train_dice: 0.0045
# 44/240, Train_loss: 0.9938 Train_dice: 0.0062
# 45/240, Train_loss: 0.9870 Train_dice: 0.0130
# 46/240, Train_loss: 0.9930 Train_dice: 0.0070
# 47/240, Train_loss: 0.9949 Train_dice: 0.0051
# 48/240, Train_loss: 0.9883 Train_dice: 0.0117
# 49/240, Train_loss: 0.9556 Train_dice: 0.0444
# 50/240, Train_loss: 0.9937 Train_dice: 0.0063
# 51/240, Train_loss: 0.9833 Train_dice: 0.0167
# 52/240, Train_loss: 0.9836 Train_dice: 0.0164
# 53/240, Train_loss: 0.9979 Train_dice: 0.0021
# 54/240, Train_loss: 0.9408 Train_dice: 0.0592
# 55/240, Train_loss: 0.9991 Train_dice: 0.0009
# 56/240, Train_loss: 0.9838 Train_dice: 0.0162
# 57/240, Train_loss: 0.9909 Train_dice: 0.0091
# 58/240, Train_loss: 0.9904 Train_dice: 0.0096
# 59/240, Train_loss: 0.9924 Train_dice: 0.0076
# 60/240, Train_loss: 0.9908 Train_dice: 0.0092
# 61/240, Train_loss: 0.9903 Train_dice: 0.0097
# 62/240, Train_loss: 0.9888 Train_dice: 0.0112
# 63/240, Train_loss: 0.9833 Train_dice: 0.0167
# 64/240, Train_loss: 0.9301 Train_dice: 0.0699
# 65/240, Train_loss: 0.9832 Train_dice: 0.0168
# 66/240, Train_loss: 0.9896 Train_dice: 0.0104
# 67/240, Train_loss: 0.9728 Train_dice: 0.0272
# 68/240, Train_loss: 0.9262 Train_dice: 0.0738
# 69/240, Train_loss: 0.9916 Train_dice: 0.0084
# 70/240, Train_loss: 0.9690 Train_dice: 0.0310
# 71/240, Train_loss: 0.9369 Train_dice: 0.0631
# 72/240, Train_loss: 0.9887 Train_dice: 0.0113
# 73/240, Train_loss: 0.9959 Train_dice: 0.0041
# 74/240, Train_loss: 0.9910 Train_dice: 0.0090
# 75/240, Train_loss: 0.9787 Train_dice: 0.0213
# 76/240, Train_loss: 0.9734 Train_dice: 0.0266
# 77/240, Train_loss: 0.9547 Train_dice: 0.0453
# 78/240, Train_loss: 0.9934 Train_dice: 0.0066
# 79/240, Train_loss: 0.9925 Train_dice: 0.0075
# 80/240, Train_loss: 0.9814 Train_dice: 0.0186
# 81/240, Train_loss: 0.9554 Train_dice: 0.0446
# 82/240, Train_loss: 0.9821 Train_dice: 0.0179
# 83/240, Train_loss: 0.9879 Train_dice: 0.0121
# 84/240, Train_loss: 0.9794 Train_dice: 0.0206
# 85/240, Train_loss: 0.9707 Train_dice: 0.0293
# 86/240, Train_loss: 0.8532 Train_dice: 0.1468
# 87/240, Train_loss: 0.9749 Train_dice: 0.0251
# 88/240, Train_loss: 0.9789 Train_dice: 0.0211
# 89/240, Train_loss: 0.9560 Train_dice: 0.0440
# 90/240, Train_loss: 0.9926 Train_dice: 0.0074
# 91/240, Train_loss: 0.9961 Train_dice: 0.0039
# 92/240, Train_loss: 0.9888 Train_dice: 0.0112
# 93/240, Train_loss: 0.9930 Train_dice: 0.0070
# 94/240, Train_loss: 0.9982 Train_dice: 0.0018
# 95/240, Train_loss: 0.9837 Train_dice: 0.0163
# 96/240, Train_loss: 0.9829 Train_dice: 0.0171
# 97/240, Train_loss: 0.9855 Train_dice: 0.0145
# 98/240, Train_loss: 0.9944 Train_dice: 0.0056
# 99/240, Train_loss: 0.9931 Train_dice: 0.0069
# 100/240, Train_loss: 0.9799 Train_dice: 0.0201
# 101/240, Train_loss: 0.9861 Train_dice: 0.0139
# 102/240, Train_loss: 0.9671 Train_dice: 0.0329
# 103/240, Train_loss: 0.9936 Train_dice: 0.0064
# 104/240, Train_loss: 0.9940 Train_dice: 0.0060
# 105/240, Train_loss: 0.9772 Train_dice: 0.0228
# 106/240, Train_loss: 0.9908 Train_dice: 0.0092
# 107/240, Train_loss: 0.9938 Train_dice: 0.0062
# 108/240, Train_loss: 0.9798 Train_dice: 0.0202
# 109/240, Train_loss: 0.9450 Train_dice: 0.0550
# 110/240, Train_loss: 0.9917 Train_dice: 0.0083
# 111/240, Train_loss: 0.9727 Train_dice: 0.0273
# 112/240, Train_loss: 0.9817 Train_dice: 0.0183
# 113/240, Train_loss: 0.9920 Train_dice: 0.0080
# 114/240, Train_loss: 0.9352 Train_dice: 0.0648
# 115/240, Train_loss: 0.9984 Train_dice: 0.0016
# 116/240, Train_loss: 0.9819 Train_dice: 0.0181
# 117/240, Train_loss: 0.9832 Train_dice: 0.0168
# 118/240, Train_loss: 0.9872 Train_dice: 0.0128
# 119/240, Train_loss: 0.9867 Train_dice: 0.0133
# 120/240, Train_loss: 0.9874 Train_dice: 0.0126
# 121/240, Train_loss: 0.9949 Train_dice: 0.0051
# 122/240, Train_loss: 0.9702 Train_dice: 0.0298
# 123/240, Train_loss: 0.9922 Train_dice: 0.0078
# 124/240, Train_loss: 0.9951 Train_dice: 0.0049
# 125/240, Train_loss: 0.9180 Train_dice: 0.0820
# 126/240, Train_loss: 0.9912 Train_dice: 0.0088
# 127/240, Train_loss: 0.9938 Train_dice: 0.0062
# 128/240, Train_loss: 0.9846 Train_dice: 0.0154
# 129/240, Train_loss: 0.9978 Train_dice: 0.0022
# 130/240, Train_loss: 0.9813 Train_dice: 0.0187
# 131/240, Train_loss: 0.9806 Train_dice: 0.0194
# 132/240, Train_loss: 1.0000 Train_dice: 0.0000
# 133/240, Train_loss: 0.9995 Train_dice: 0.0005
# 134/240, Train_loss: 0.9852 Train_dice: 0.0148
# 135/240, Train_loss: 0.9806 Train_dice: 0.0194
# 136/240, Train_loss: 0.9897 Train_dice: 0.0103
# 137/240, Train_loss: 0.9836 Train_dice: 0.0164
# 138/240, Train_loss: 0.9877 Train_dice: 0.0123
# 139/240, Train_loss: 0.9278 Train_dice: 0.0722
# 140/240, Train_loss: 0.9843 Train_dice: 0.0157
# 141/240, Train_loss: 0.9907 Train_dice: 0.0093
# 142/240, Train_loss: 0.9843 Train_dice: 0.0157
# 143/240, Train_loss: 0.9050 Train_dice: 0.0950
# 144/240, Train_loss: 0.9906 Train_dice: 0.0094
# 145/240, Train_loss: 0.9423 Train_dice: 0.0577
# 146/240, Train_loss: 0.9351 Train_dice: 0.0649
# 147/240, Train_loss: 0.9918 Train_dice: 0.0082
# 148/240, Train_loss: 0.9925 Train_dice: 0.0075
# 149/240, Train_loss: 0.9884 Train_dice: 0.0116
# 150/240, Train_loss: 0.9775 Train_dice: 0.0225
# 151/240, Train_loss: 0.9765 Train_dice: 0.0235
# 152/240, Train_loss: 0.9502 Train_dice: 0.0498
# 153/240, Train_loss: 0.9870 Train_dice: 0.0130
# 154/240, Train_loss: 0.9916 Train_dice: 0.0084
# 155/240, Train_loss: 0.9826 Train_dice: 0.0174
# 156/240, Train_loss: 0.9421 Train_dice: 0.0579
# 157/240, Train_loss: 0.9791 Train_dice: 0.0209
# 158/240, Train_loss: 0.9869 Train_dice: 0.0131
# 159/240, Train_loss: 0.9690 Train_dice: 0.0310
# 160/240, Train_loss: 0.9859 Train_dice: 0.0141
# 161/240, Train_loss: 0.8650 Train_dice: 0.1350
# 162/240, Train_loss: 0.9698 Train_dice: 0.0302
# 163/240, Train_loss: 0.9858 Train_dice: 0.0142
# 164/240, Train_loss: 0.9536 Train_dice: 0.0464
# 165/240, Train_loss: 0.9940 Train_dice: 0.0060
# 166/240, Train_loss: 0.9932 Train_dice: 0.0068
# 167/240, Train_loss: 0.9876 Train_dice: 0.0124
# 168/240, Train_loss: 0.9927 Train_dice: 0.0073
# 169/240, Train_loss: 0.9985 Train_dice: 0.0015
# 170/240, Train_loss: 0.9859 Train_dice: 0.0141
# 171/240, Train_loss: 0.9845 Train_dice: 0.0155
# 172/240, Train_loss: 0.9870 Train_dice: 0.0130
# 173/240, Train_loss: 0.9948 Train_dice: 0.0052
# 174/240, Train_loss: 0.9974 Train_dice: 0.0026
# 175/240, Train_loss: 0.9767 Train_dice: 0.0233
# 176/240, Train_loss: 0.9917 Train_dice: 0.0083
# 177/240, Train_loss: 0.9600 Train_dice: 0.0400
# 178/240, Train_loss: 0.9908 Train_dice: 0.0092
# 179/240, Train_loss: 0.9889 Train_dice: 0.0111
# 180/240, Train_loss: 0.9787 Train_dice: 0.0213
# 181/240, Train_loss: 0.9876 Train_dice: 0.0124
# 182/240, Train_loss: 0.9933 Train_dice: 0.0067
# 183/240, Train_loss: 0.9854 Train_dice: 0.0146
# 184/240, Train_loss: 0.9518 Train_dice: 0.0482
# 185/240, Train_loss: 0.9887 Train_dice: 0.0113
# 186/240, Train_loss: 0.9709 Train_dice: 0.0291
# 187/240, Train_loss: 0.9770 Train_dice: 0.0230
# 188/240, Train_loss: 0.9955 Train_dice: 0.0045
# 189/240, Train_loss: 0.9222 Train_dice: 0.0778
# 190/240, Train_loss: 0.9989 Train_dice: 0.0011
# 191/240, Train_loss: 0.9680 Train_dice: 0.0320
# 192/240, Train_loss: 0.9842 Train_dice: 0.0158
# 193/240, Train_loss: 0.9876 Train_dice: 0.0124
# 194/240, Train_loss: 0.9913 Train_dice: 0.0087
# 195/240, Train_loss: 0.9884 Train_dice: 0.0116
# 196/240, Train_loss: 0.9906 Train_dice: 0.0094
# 197/240, Train_loss: 0.9745 Train_dice: 0.0255
# 198/240, Train_loss: 0.9959 Train_dice: 0.0041
# 199/240, Train_loss: 0.9964 Train_dice: 0.0036
# 200/240, Train_loss: 0.9052 Train_dice: 0.0948
# 201/240, Train_loss: 0.9907 Train_dice: 0.0093
# 202/240, Train_loss: 0.9938 Train_dice: 0.0062
# 203/240, Train_loss: 0.9715 Train_dice: 0.0285
# 204/240, Train_loss: 0.9933 Train_dice: 0.0067
# 205/240, Train_loss: 0.9926 Train_dice: 0.0074
# 206/240, Train_loss: 0.9856 Train_dice: 0.0144
# 207/240, Train_loss: 0.9980 Train_dice: 0.0020
# 208/240, Train_loss: 0.9983 Train_dice: 0.0017
# 209/240, Train_loss: 0.9812 Train_dice: 0.0188
# 210/240, Train_loss: 0.9742 Train_dice: 0.0258
# 211/240, Train_loss: 0.9937 Train_dice: 0.0063
# 212/240, Train_loss: 0.9879 Train_dice: 0.0121
# 213/240, Train_loss: 0.9870 Train_dice: 0.0130
# 214/240, Train_loss: 0.9253 Train_dice: 0.0747
# 215/240, Train_loss: 0.9827 Train_dice: 0.0173
# 216/240, Train_loss: 0.9857 Train_dice: 0.0143
# 217/240, Train_loss: 0.9743 Train_dice: 0.0257
# 218/240, Train_loss: 0.9068 Train_dice: 0.0932
# 219/240, Train_loss: 0.9894 Train_dice: 0.0106
# 220/240, Train_loss: 0.9415 Train_dice: 0.0585
# 221/240, Train_loss: 0.9436 Train_dice: 0.0564
# 222/240, Train_loss: 0.9872 Train_dice: 0.0128
# 223/240, Train_loss: 0.9935 Train_dice: 0.0065
# 224/240, Train_loss: 0.9879 Train_dice: 0.0121
# 225/240, Train_loss: 0.9775 Train_dice: 0.0225
# 226/240, Train_loss: 0.9742 Train_dice: 0.0258
# 227/240, Train_loss: 0.9498 Train_dice: 0.0502
# 228/240, Train_loss: 0.9886 Train_dice: 0.0114
# 229/240, Train_loss: 0.9950 Train_dice: 0.0050
# 230/240, Train_loss: 0.9855 Train_dice: 0.0145
# 231/240, Train_loss: 0.9392 Train_dice: 0.0608
# 232/240, Train_loss: 0.9797 Train_dice: 0.0203
# 233/240, Train_loss: 0.9885 Train_dice: 0.0115
# 234/240, Train_loss: 0.9767 Train_dice: 0.0233
# 235/240, Train_loss: 0.9699 Train_dice: 0.0301
# 236/240, Train_loss: 0.8344 Train_dice: 0.1656
# 237/240, Train_loss: 0.9716 Train_dice: 0.0284
# 238/240, Train_loss: 0.9790 Train_dice: 0.0210
# 239/240, Train_loss: 0.9516 Train_dice: 0.0484
# 240/240, Train_loss: 0.9915 Train_dice: 0.0085
# --------------------
# Epoch_loss: 0.9784
# Epoch_metric: 0.0216
# test_loss_epoch: 0.9865
# test_dice_epoch: 0.0148
# current epoch: 4 current mean dice: 0.0171
# best mean dice: 0.0148 at epoch: 4
# Time Taken:  3430.6105687618256
# Maximum GPU Memory taken for training:  0
# Maximum CPU Memory taken for training:  0
# train completed, best_metric: 0.0148 at epoch: 4
# ----------
# epoch 5/10
# 1/240, Train_loss: 0.9934 Train_dice: 0.0066
# 2/240, Train_loss: 0.9902 Train_dice: 0.0098
# 3/240, Train_loss: 0.9889 Train_dice: 0.0111
# 4/240, Train_loss: 0.9373 Train_dice: 0.0627
# 5/240, Train_loss: 0.9836 Train_dice: 0.0164
# 6/240, Train_loss: 0.9905 Train_dice: 0.0095
# 7/240, Train_loss: 0.9829 Train_dice: 0.0171
# 8/240, Train_loss: 0.9210 Train_dice: 0.0790
# 9/240, Train_loss: 0.9934 Train_dice: 0.0066
# 10/240, Train_loss: 0.9704 Train_dice: 0.0296
# 11/240, Train_loss: 0.9464 Train_dice: 0.0536
# 12/240, Train_loss: 0.9917 Train_dice: 0.0083
# 13/240, Train_loss: 0.9951 Train_dice: 0.0049
# 14/240, Train_loss: 0.9892 Train_dice: 0.0108
# 15/240, Train_loss: 0.9843 Train_dice: 0.0157
# 16/240, Train_loss: 0.9786 Train_dice: 0.0214
# 17/240, Train_loss: 0.9608 Train_dice: 0.0392
# 18/240, Train_loss: 0.9919 Train_dice: 0.0081
# 19/240, Train_loss: 0.9950 Train_dice: 0.0050
# 20/240, Train_loss: 0.9856 Train_dice: 0.0144
# 21/240, Train_loss: 0.9570 Train_dice: 0.0430
# 22/240, Train_loss: 0.9841 Train_dice: 0.0159
# 23/240, Train_loss: 0.9900 Train_dice: 0.0100
# 24/240, Train_loss: 0.9760 Train_dice: 0.0240
# 25/240, Train_loss: 0.9737 Train_dice: 0.0263
# 26/240, Train_loss: 0.8665 Train_dice: 0.1335
# 27/240, Train_loss: 0.9761 Train_dice: 0.0239
# 28/240, Train_loss: 0.9833 Train_dice: 0.0167
# 29/240, Train_loss: 0.9716 Train_dice: 0.0284
# 30/240, Train_loss: 0.9939 Train_dice: 0.0061
# 31/240, Train_loss: 0.9971 Train_dice: 0.0029
# 32/240, Train_loss: 0.9958 Train_dice: 0.0042
# 33/240, Train_loss: 0.9955 Train_dice: 0.0045
# 34/240, Train_loss: 0.9976 Train_dice: 0.0024
# 35/240, Train_loss: 0.9865 Train_dice: 0.0135
# 36/240, Train_loss: 0.9876 Train_dice: 0.0124
# 37/240, Train_loss: 0.9972 Train_dice: 0.0028
# 38/240, Train_loss: 0.9958 Train_dice: 0.0042
# 39/240, Train_loss: 0.9927 Train_dice: 0.0073
# 40/240, Train_loss: 0.9754 Train_dice: 0.0246
# 41/240, Train_loss: 0.9880 Train_dice: 0.0120
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 train(unet, data_in, loss_function, optimizer, 10, model_dir, test_interval=2,start_from=1)
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\utils\train.py:71, in train(model, data_in, loss, optim, max_epochs, model_dir, test_interval, device, start_from)
#      69 train_step = 0
#      70 epoch_metric_train = 0
# ---> 71 for batch_data in train_loader:
#      73     train_step += 1
#      75     volume = batch_data["image"]
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\torch\utils\data\dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\torch\utils\data\dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\data\dataset.py:107, in Dataset.__getitem__(self, index)
#     104 if isinstance(index, collections.abc.Sequence):
#     105     # dataset[[1, 3, 4]]
#     106     return Subset(dataset=self, indices=index)
# --> 107 return self._transform(index)
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\data\dataset.py:93, in Dataset._transform(self, index)
#      89 """
#      90 Fetch single data item from `self.data`.
#      91 """
#      92 data_i = self.data[index]
# ---> 93 return apply_transform(self.transform, data_i) if self.transform is not None else data_i
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\transforms\transform.py:102, in apply_transform(transform, data, map_items, unpack_items, log_stats)
#     100     if isinstance(data, (list, tuple)) and map_items:
#     101         return [_apply_transform(transform, item, unpack_items) for item in data]
# --> 102     return _apply_transform(transform, data, unpack_items)
#     103 except Exception as e:
#     104     # if in debug mode, don't swallow exception so that the breakpoint
#     105     # appears where the exception was raised.
#     106     if MONAIEnvVars.debug():
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\transforms\transform.py:66, in _apply_transform(transform, parameters, unpack_parameters)
#      63 if isinstance(parameters, tuple) and unpack_parameters:
#      64     return transform(*parameters)
# ---> 66 return transform(parameters)
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\transforms\compose.py:174, in Compose.__call__(self, input_)
#     172 def __call__(self, input_):
#     173     for _transform in self.transforms:
# --> 174         input_ = apply_transform(_transform, input_, self.map_items, self.unpack_items, self.log_stats)
#     175     return input_
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\transforms\transform.py:102, in apply_transform(transform, data, map_items, unpack_items, log_stats)
#     100     if isinstance(data, (list, tuple)) and map_items:
#     101         return [_apply_transform(transform, item, unpack_items) for item in data]
# --> 102     return _apply_transform(transform, data, unpack_items)
#     103 except Exception as e:
#     104     # if in debug mode, don't swallow exception so that the breakpoint
#     105     # appears where the exception was raised.
#     106     if MONAIEnvVars.debug():
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\transforms\transform.py:66, in _apply_transform(transform, parameters, unpack_parameters)
#      63 if isinstance(parameters, tuple) and unpack_parameters:
#      64     return transform(*parameters)
# ---> 66 return transform(parameters)
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\transforms\io\dictionary.py:154, in LoadImaged.__call__(self, data, reader)
#     152 d = dict(data)
#     153 for key, meta_key, meta_key_postfix in self.key_iterator(d, self.meta_keys, self.meta_key_postfix):
# --> 154     data = self._loader(d[key], reader)
#     155     if self._loader.image_only:
#     156         d[key] = data
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\transforms\io\array.py:275, in LoadImage.__call__(self, filename, reader)
#     273 img_array: NdarrayOrTensor
#     274 img_array, meta_data = reader.get_data(img)
# --> 275 img_array = convert_to_dst_type(img_array, dst=img_array, dtype=self.dtype)[0]
#     276 if not isinstance(meta_data, dict):
#     277     raise ValueError("`meta_data` must be a dict.")
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\utils\type_conversion.py:370, in convert_to_dst_type(src, dst, dtype, wrap_sequence, device, safe)
#     368     output_type = type(dst)
#     369 output: NdarrayTensor
# --> 370 output, _type, _device = convert_data_type(
#     371     data=src, output_type=output_type, device=device, dtype=dtype, wrap_sequence=wrap_sequence, safe=safe
#     372 )
#     373 if copy_meta and isinstance(output, monai.data.MetaTensor):
#     374     output.copy_meta_from(dst)
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\utils\type_conversion.py:317, in convert_data_type(data, output_type, device, dtype, wrap_sequence, safe)
#     315     return data_, orig_type, orig_device
#     316 if issubclass(output_type, np.ndarray):
# --> 317     data_ = convert_to_numpy(data, dtype=dtype_, wrap_sequence=wrap_sequence, safe=safe)
#     318     return data_, orig_type, orig_device
#     319 elif has_cp and issubclass(output_type, cp.ndarray):
#
# File c:\Users\envy\Desktop\Prostate_MRI\Prostate_Lesion\packages\lib\site-packages\monai\utils\type_conversion.py:213, in convert_to_numpy(data, dtype, wrap_sequence, safe)
#     210     return {k: convert_to_numpy(v, dtype=dtype) for k, v in data.items()}
#     212 if isinstance(data, np.ndarray) and data.ndim > 0:
# --> 213     data = np.ascontiguousarray(data)
#     215 return data
#
# KeyboardInterrupt:

# %% [markdown]
# # Plot

# %%
from utils.view import  plt_metrices

path = OUT_DIR
if (os.path.exists(path)):
    plt_metrices(path)

# %%
from monai.utils import first
from monai.transforms import(
    Activations,
)

import matplotlib.pyplot as plt

import os
from glob import glob
import numpy as np

from monai.inferers import sliding_window_inference

# %%
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from monai.networks.nets import UNet
from monai.networks.layers import Norm


model = UNet(
    spatial_dims=3,
    in_channels=4,
    out_channels=1,
    channels=( 64, 128, 256,512), 
    strides=(2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

# %%
import os.path

path = OUT_DIR+'unet/'+  "best_metric_model.pth"

if (os.path.exists(path)):
    model.load_state_dict(torch.load(
        os.path.join(path)))
# model.eval()

# %%
spatial_size = [128,128,16]

# %%
sw_batch_size = 4
roi_size = spatial_size
with torch.no_grad():
    test_patient = first(test_loader)
    t_volume = test_patient['image']
    #t_segmentation = test_patient['seg']
    print(t_volume.shape)
    test_outputs = sliding_window_inference(t_volume.to(device), roi_size, sw_batch_size, model)
    sigmoid_activation = Activations(sigmoid=True)
    test_outputs = sigmoid_activation(test_outputs)
    test_outputs = test_outputs > 0.8
        
    for i in range(spatial_size[2]):
        # plot the slice [:, :, 80]
        plt.figure("check", (18, 6))
        plt.subplot(1, 3, 1)
        plt.title(f"image {i}")
        plt.imshow(test_patient["image"][0, 0, :, :, i], cmap="gray")
        plt.subplot(1, 3, 2)
        plt.title(f"label {i}")
        plt.imshow(test_patient["label"][0, 0, :, :, i] != 0)
        plt.subplot(1, 3, 3)
        plt.title(f"output {i}")
        plt.imshow(test_outputs.detach().cpu()[0, 0, :, :, i])
        plt.show()
# Out:
# torch.Size([1, 4, 128, 128, 16])
